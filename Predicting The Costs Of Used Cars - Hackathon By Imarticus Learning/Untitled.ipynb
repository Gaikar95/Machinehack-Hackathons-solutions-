# %%
import pandas as pd
import numpy as np
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import seaborn as sns
import regex as re
pd.set_option('display.max_rows', None)

# %%
train = pd.read_excel("Data_Train.xlsx")
test=pd.read_excel("Data_Test.xlsx")

# %%
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# 3        NaN   6.00
# 4        NaN  17.74

# %%
train[train['Engine'].isnull()].head(100)
# Out:
#                                               Name    Location  Year  \
# 194                             Honda City 1.5 GXI   Ahmedabad  2007
# 208                           Maruti Swift 1.3 VXi     Kolkata  2010
# 733                           Maruti Swift 1.3 VXi     Chennai  2006
# 749                   Land Rover Range Rover 3.0 D      Mumbai  2008
# 1294                             Honda City 1.3 DX       Delhi  2009
# 1327                          Maruti Swift 1.3 ZXI   Hyderabad  2015
# 1385                            Honda City 1.5 GXI        Pune  2004
# 1460  Land Rover Range Rover Sport 2005 2012 Sport  Coimbatore  2008
# 2074                          Maruti Swift 1.3 LXI        Pune  2011
# 2096                     Hyundai Santro LP zipPlus  Coimbatore  2004
# 2264                           Toyota Etios Liva V        Pune  2012
# 2325                      Maruti Swift 1.3 VXI ABS        Pune  2015
# 2335                          Maruti Swift 1.3 VXi      Mumbai  2007
# 2530                       BMW 5 Series 520d Sedan       Kochi  2014
# 2542               Hyundai Santro GLS II - Euro II   Bangalore  2011
# 2623                       BMW 5 Series 520d Sedan        Pune  2012
# 2668                          Maruti Swift 1.3 VXi     Kolkata  2014
# 2737                             Maruti Wagon R Vx      Jaipur  2001
# 2780               Hyundai Santro GLS II - Euro II        Pune  2009
# 2842               Hyundai Santro GLS II - Euro II   Bangalore  2012
# 3272                       BMW 5 Series 520d Sedan      Mumbai  2008
# 3404                          Maruti Swift 1.3 VXi      Jaipur  2006
# 3520                       BMW 5 Series 520d Sedan       Delhi  2012
# 3522               Hyundai Santro GLS II - Euro II       Kochi  2012
# 3810                   Honda CR-V AT With Sun Roof     Kolkata  2013
# 4011                        Fiat Punto 1.3 Emotion        Pune  2011
# 4152                  Land Rover Range Rover 3.0 D      Mumbai  2003
# 4229                        Hyundai Santro Xing XG   Bangalore  2005
# 4577                       BMW 5 Series 520d Sedan       Delhi  2012
# 4604                     Honda Jazz Select Edition        Pune  2011
# 4697                        Fiat Punto 1.2 Dynamic       Kochi  2017
# 4712                        Hyundai Santro Xing XG        Pune  2003
# 4952                        Fiat Punto 1.4 Emotion     Kolkata  2010
# 5015                          Maruti Swift 1.3 VXi       Delhi  2006
# 5185                          Maruti Swift 1.3 LXI       Delhi  2012
# 5270                            Honda City 1.5 GXI   Bangalore  2002
#
#       Kilometers_Driven Fuel_Type Transmission      Owner_Type     Mileage  \
# 194               60006    Petrol       Manual           First    0.0 kmpl
# 208               42001    Petrol       Manual           First   16.1 kmpl
# 733               97800    Petrol       Manual           Third   16.1 kmpl
# 749               55001    Diesel    Automatic          Second    0.0 kmpl
# 1294              55005    Petrol       Manual           First   12.8 kmpl
# 1327              50295    Petrol       Manual           First   16.1 kmpl
# 1385             115000    Petrol       Manual          Second    0.0 kmpl
# 1460              69078    Petrol       Manual           First    0.0 kmpl
# 2074              24255    Petrol       Manual           First   16.1 kmpl
# 2096              52146    Petrol       Manual           First    0.0 kmpl
# 2264              24500    Petrol       Manual          Second   18.3 kmpl
# 2325              67000    Petrol       Manual           First   16.1 kmpl
# 2335              55000    Petrol       Manual          Second   16.1 kmpl
# 2530              64158    Diesel    Automatic           First  18.48 kmpl
# 2542              65000    Petrol       Manual          Second    0.0 kmpl
# 2623              95000    Diesel    Automatic          Second  18.48 kmpl
# 2668              32986    Petrol       Manual           First   16.1 kmpl
# 2737             200000    Petrol       Manual           First   12.0 kmpl
# 2780             100000    Petrol       Manual           First    0.0 kmpl
# 2842              43000    Petrol       Manual           First    0.0 kmpl
# 3272              81000    Diesel    Automatic          Second  18.48 kmpl
# 3404             125000    Petrol       Manual  Fourth & Above   16.1 kmpl
# 3520              90000    Diesel    Automatic           First  18.48 kmpl
# 3522              66400    Petrol       Manual           First    0.0 kmpl
# 3810              27000    Petrol    Automatic           First   14.0 kmpl
# 4011              45271    Diesel       Manual           First   20.3 kmpl
# 4152              75000    Diesel    Automatic          Second    0.0 kmpl
# 4229              79000    Petrol       Manual          Second   17.0 kmpl
# 4577              72000    Diesel    Automatic           Third  18.48 kmpl
# 4604              98000    Petrol       Manual           First   16.7 kmpl
# 4697              17941    Petrol       Manual           First   15.7 kmpl
# 4712              80000    Petrol       Manual          Second   17.0 kmpl
# 4952              47000    Petrol       Manual           First   14.6 kmpl
# 5015              63000    Petrol       Manual           First   16.1 kmpl
# 5185              52000    Petrol       Manual           First   16.1 kmpl
# 5270              53000    Petrol       Manual          Second    0.0 kmpl
#
#      Engine Power  Seats New_Price  Price
# 194     NaN   NaN    NaN       NaN   2.95
# 208     NaN   NaN    NaN       NaN   2.11
# 733     NaN   NaN    NaN       NaN   1.75
# 749     NaN   NaN    NaN       NaN  26.50
# 1294    NaN   NaN    NaN       NaN   3.20
# 1327    NaN   NaN    NaN       NaN   5.80
# 1385    NaN   NaN    NaN       NaN   1.50
# 1460    NaN   NaN    NaN       NaN  40.88
# 2074    NaN   NaN    NaN       NaN   3.15
# 2096    NaN   NaN    NaN       NaN   1.93
# 2264    NaN   NaN    NaN       NaN   2.95
# 2325    NaN   NaN    NaN       NaN   4.70
# 2335    NaN   NaN    NaN       NaN   1.75
# 2530    NaN   NaN    NaN       NaN  17.89
# 2542    NaN   NaN    NaN       NaN   3.15
# 2623    NaN   NaN    NaN       NaN  18.00
# 2668    NaN   NaN    NaN       NaN   4.24
# 2737    NaN   NaN    NaN       NaN   0.70
# 2780    NaN   NaN    NaN       NaN   1.60
# 2842    NaN   NaN    NaN       NaN   3.25
# 3272    NaN   NaN    NaN       NaN  10.50
# 3404    NaN   NaN    NaN       NaN   2.35
# 3520    NaN   NaN    NaN       NaN  14.50
# 3522    NaN   NaN    NaN       NaN   2.66
# 3810    NaN   NaN    NaN       NaN  11.99
# 4011    NaN   NaN    NaN       NaN   2.60
# 4152    NaN   NaN    NaN       NaN  16.11
# 4229    NaN   NaN    NaN       NaN   1.65
# 4577    NaN   NaN    NaN       NaN  13.85
# 4604    NaN   NaN    NaN       NaN   3.15
# 4697    NaN   NaN    NaN       NaN   3.93
# 4712    NaN   NaN    NaN       NaN   0.90
# 4952    NaN   NaN    NaN       NaN   1.49
# 5015    NaN   NaN    NaN       NaN   1.60
# 5185    NaN   NaN    NaN       NaN   3.65
# 5270    NaN   NaN    NaN       NaN   1.85

# %%
# train[train['Model_Name'].str.contains('swift')].head(100)

# %%
def preprocesing(df):
    columns_to_split = ['Mileage','Engine','Power']
    for column in columns_to_split:
        df[[column + '_Value', column + '_Unit']] = df[column].str.split(' ', expand=True)
        df[column + '_Value']= df[column + '_Value'].replace('null', np.nan).astype(float) 
        df = df.drop(column, axis=1)
    df.drop(['Engine_Unit','Power_Unit','New_Price'],axis=1,inplace= True)
    df.dropna(subset=['Mileage_Value'],inplace= True)
   
    #cleaning Name column
    Fuel_Types = df['Fuel_Type'].unique()
    for Fuel_Type in Fuel_Types:
        df['Name'] = df['Name'].str.replace(Fuel_Type, '')
        
    df['Name'] = df['Name'].str.lower()
    
    name_corrections = [('cooper', ''),('land rover', 'Land-Rover'),('wagon r', 'wagon-r'), ('f type', 'f-type'),('range rover','range-rover'),
                        ('redi go', 'redi-go'),('grand i10','i10'),('grande punto','grande-punto'),('s cross','s-cross'),('kuv 100','kuv-100'),
                        ('grand vitara','grand-vitara'),('vitara brezza','vitara-brezza'),('alto 800','alto'),('alto k10','alto-k10'),
                        ('zen estilo','zen-estilo'),('innova crysta','innova-crysta'),('zest ','zest-'),('santro xing','santro-xing')
                       
                       ]
    for old, new in name_corrections:
        df['Name'] = df['Name'].str.replace(old, new)
        
    df[['Manufacturer_Name', 'Model_Name']] = df['Name'].str.split(' ',n=1, expand=True)
    df = df.drop('Name', axis=1)
    
    df['ABS'] = df['Model_Name'].str.contains('abs', case=False).astype(int)
    df['Model_Name'] = df['Model_Name'].str.replace('abs', '')

    # Extract BS version using regular expression
    df['BS_Version'] = df['Model_Name'].str.extract(r'(bs\s*-*[ivxlc123456]*\s*\d*)')
    df['Model_Name'] = df['Model_Name'].str.replace(r'(bs\s*-*[ivxlc123456]*\s*\d*)', '', regex=True).str.strip()
    df['BS_Version'] = df['BS_Version'].str.replace(r'\s*\-*','',regex=True)
    bs_version_mapping = {'bsiv': 4, 'bsiii': 3, 'bs3': 3, 'bsii': 2, np.nan: 0}
    df['BS_Version'] = df['BS_Version'].map(bs_version_mapping)
    
    df['Model_Name'] = df['Model_Name'].str.replace(r'(\d\s*-*seater)|(\d\s*-*str)', '', regex=True).str.strip()
    df['Model_Name'] = df['Model_Name'].str.replace(r'(20\d\d\s*-*20\d\d)', '', regex=True).str.strip()
    df['Model_Name'] = df['Model_Name'].str.replace(' at| mt| amt| automatic| manual', '',  regex=True).str.strip()
    
    df[['Model_subName', 'Model_specific']] = df['Model_Name'].str.split(' ',n=1, expand=True)
    
    columns_with_nulls = ['Seats', 'Engine_Value', 'Power_Value']
    for column in columns_with_nulls:
        df[column].fillna(df.groupby(['Manufacturer_Name'])[column].transform('mean'), inplace=True)
    df['Seats']=df['Seats'].round()
        
    df['Power_Value'].fillna(53.3, inplace=True)
    df['Model_specific'].fillna('std', inplace=True)
    
    return df

# %%
train['Seats'].unique()
# Out:
# array([ 5.,  7.,  8.,  4.,  6.,  2., nan, 10.,  9.,  0.])

# %%
train = preprocesing(train)
test= preprocesing(test)

# %%
df= train

# %%
df.head(100)
# Out:
#       Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0       Mumbai  2010              72000       CNG       Manual
# 1         Pune  2015              41000    Diesel       Manual
# 2      Chennai  2011              46000    Petrol       Manual
# 3      Chennai  2012              87000    Diesel       Manual
# 4   Coimbatore  2013              40670    Diesel    Automatic
# 5    Hyderabad  2012              75000       LPG       Manual
# 6       Jaipur  2013              86999    Diesel       Manual
# 7       Mumbai  2016              36000    Diesel    Automatic
# 8         Pune  2013              64430    Diesel       Manual
# 9      Chennai  2012              65932    Diesel       Manual
# 10       Kochi  2018              25692    Petrol       Manual
# 11     Kolkata  2012              60000    Petrol    Automatic
# 12      Jaipur  2015              64424    Diesel       Manual
# 13       Delhi  2014              72000    Diesel    Automatic
# 14        Pune  2012              85000    Diesel    Automatic
# 15       Delhi  2014             110000    Diesel       Manual
# 16       Kochi  2016              58950    Diesel       Manual
# 17      Jaipur  2017              25000    Diesel       Manual
# 18       Kochi  2014              77469    Diesel       Manual
# 19   Bangalore  2014              78500    Diesel    Automatic
# 20       Kochi  2014              32982    Diesel    Automatic
# 21   Bangalore  2015              55392    Diesel       Manual
# 22      Mumbai  2015              55985    Petrol    Automatic
# 23     Kolkata  2010              45807    Petrol       Manual
# 24     Kolkata  2010              33000    Petrol    Automatic
# 25      Mumbai  2012              51920    Petrol       Manual
# 26   Hyderabad  2012              54000    Diesel       Manual
# 27   Hyderabad  2013              54000    Petrol       Manual
# 28       Kochi  2018              37430    Petrol       Manual
# 29      Mumbai  2007             262000    Diesel       Manual
# 30   Bangalore  2013              62000    Diesel       Manual
# 31       Delhi  2012              87615    Petrol       Manual
# 32   Bangalore  2013              72000    Diesel    Automatic
# 33     Kolkata  2010              35000    Diesel    Automatic
# 34  Coimbatore  2014              55431    Petrol       Manual
# 35      Jaipur  2009              83816    Petrol       Manual
# 36       Kochi  2018              50075    Diesel       Manual
# 37       Delhi  2017              52000    Petrol       Manual
# 38        Pune  2013              85000    Diesel    Automatic
# 39     Chennai  2013              62000    Diesel       Manual
# 40       Delhi  2008              90000    Petrol       Manual
# 41       Kochi  2014              19698    Petrol       Manual
# 42  Coimbatore  2017              22033    Diesel       Manual
# 43       Kochi  2014              35487    Petrol       Manual
# 44   Bangalore  2014              46374    Petrol    Automatic
# 45      Mumbai  2016              52001    Petrol    Automatic
# 46   Ahmedabad  2008              58005    Diesel       Manual
# 47   Bangalore  2012              70704    Petrol       Manual
# 48      Jaipur  2014              75000    Diesel       Manual
# 49      Jaipur  2012              75800    Diesel       Manual
# 50       Kochi  2015              13648    Diesel    Automatic
# 51       Delhi  2014              52000    Diesel       Manual
# 52     Kolkata  2014              53000    Diesel       Manual
# 53       Delhi  2013              65650    Diesel       Manual
# 54     Chennai  2015              54000    Petrol       Manual
# 55     Kolkata  2015              39000    Petrol       Manual
# 56       Kochi  2017              16542    Petrol       Manual
# 57     Kolkata  2010              32000    Petrol       Manual
# 58   Hyderabad  2010             121812    Diesel    Automatic
# 59   Hyderabad  2010              39300    Petrol       Manual
# 60      Mumbai  2017              22000    Diesel       Manual
# 61   Bangalore  2010              72000    Diesel       Manual
# 62       Delhi  2015              58000    Petrol    Automatic
# 63        Pune  2011              65000    Diesel       Manual
# 64     Chennai  2016             178000    Diesel       Manual
# 65      Jaipur  2012              65664    Diesel    Automatic
# 66      Mumbai  2007              63000    Petrol    Automatic
# 67  Coimbatore  2019              15369    Diesel    Automatic
# 68        Pune  2016              63000    Diesel       Manual
# 69      Mumbai  2018              13000    Diesel       Manual
# 70      Mumbai  2008              73000    Petrol    Automatic
# 71      Mumbai  2015              55729    Diesel       Manual
# 72       Kochi  2012              45178    Petrol    Automatic
# 73       Kochi  2015              56066    Diesel       Manual
# 74  Coimbatore  2016              37300    Petrol    Automatic
# 75       Delhi  2014              56000    Diesel    Automatic
# 76      Jaipur  2008             111111    Diesel       Manual
# 77     Chennai  2006             230000    Petrol       Manual
# 78   Hyderabad  2012             104000    Diesel       Manual
# 79   Hyderabad  2005              87591    Petrol       Manual
# 80      Jaipur  2012              95100    Diesel       Manual
# 81        Pune  2017              70000    Petrol       Manual
# 82       Kochi  2016              54944    Petrol       Manual
# 83   Hyderabad  2012              70337    Diesel       Manual
# 84      Jaipur  2013              99638    Diesel       Manual
# 85       Delhi  2009              52000    Petrol       Manual
# 86       Delhi  2011              75000    Diesel    Automatic
# 87        Pune  2009              95980    Petrol       Manual
# 88   Bangalore  2016              16000    Petrol       Manual
# 89   Hyderabad  2007              73745    Petrol       Manual
# 90      Mumbai  2016              18949    Petrol       Manual
# 91       Delhi  2014             107000    Diesel       Manual
# 92  Coimbatore  2018              48367    Diesel    Automatic
# 93       Delhi  2013              57000    Diesel       Manual
# 94       Delhi  2014              58000    Diesel       Manual
# 95     Kolkata  2015              30000    Diesel       Manual
# 96     Kolkata  2013              34212    Diesel       Manual
# 97   Ahmedabad  2010              70002    Diesel       Manual
# 98   Bangalore  2016              62000    Petrol       Manual
# 99       Delhi  2010              62001    Petrol       Manual
#
#         Owner_Type  Seats  Price  Mileage_Value Mileage_Unit  Engine_Value  \
# 0            First    5.0   1.75          26.60        km/kg         998.0
# 1            First    5.0  12.50          19.67         kmpl        1582.0
# 2            First    5.0   4.50          18.20         kmpl        1199.0
# 3            First    7.0   6.00          20.77         kmpl        1248.0
# 4           Second    5.0  17.74          15.20         kmpl        1968.0
# 5            First    5.0   2.35          21.10        km/kg         814.0
# 6            First    5.0   3.50          23.08         kmpl        1461.0
# 16    98.600000             honda                     amaze s i-dtech    0
# 17    74.000000            maruti                      swift ddis vdi    0
# 18    83.800000           renault               duster 85ps  rxl plus    0
# 19   167.620000     mercedes-benz  new c-class c 220 cdi be avantgare    0
# 20   190.000000               bmw                       3 series 320d    0
# 21    88.500000            maruti              s-cross ddis 200 alpha    0
# 22   177.010000              audi              a6  35 tfsi technology    0
# 23    80.000000           hyundai                       i20 1.2 magna    0
# 24   103.600000        volkswagen                     vento  highline    0
# 25   116.300000             honda              city corporate edition    0
# 26    63.100000            nissan                           micra  xv    0
# 27    67.100000            maruti                       alto-k10  vxi    0
# 28    88.700000             honda                       wrv i-vtec vx    0
# 29   102.000000            toyota                        innova 2.5 v    0
# 30   108.450000           renault              duster 110ps  rxz pack    0
# 31   138.100000            toyota                     corolla altis g    0
# 32   184.000000          mahindra                ssangyong rexton rx7    0
# 33   179.500000              audi                          a6 2.7 tdi    0
# 34   103.500000        volkswagen                  vento 1.6 highline    0
# 35    64.000000            maruti                         wagon-r lxi    0
# 36    88.500000            maruti              vitara-brezza zdi plus    0
# 37    82.000000          mahindra          kuv-100 mfalcon g80 k6  aw    0
# 38   254.800000     mercedes-benz                  m-class ml 350 cdi    0
# 39    73.900000        volkswagen                polo  trendline 1.2l    0
# 40    46.300000            maruti                            alto lxi    0
# 41    37.500000              tata                          nano lx se    0
# 42    77.000000          mahindra    kuv-100 mfalcon d75 k8 dual tone    0
# 43    82.900000           hyundai              i20 magna optional 1.2    0
# 44   149.920000           hyundai               elantra 2.0 sx option    0
# 45   138.030000            toyota                     corolla altis g    0
# 46   112.200000           hyundai                        elantra crdi    0
# 47   163.700000            toyota                innova-crysta 2.7 gx    0
# 48    71.000000           hyundai                    xcent 1.1 crdi s    0
# 49   105.000000          mahindra                        thar crde ac    0
# 50   174.330000              audi     a4 2.0 tdi 177 bhp premium plus    0
# 51    74.000000            maruti                           swift ldi    0
# 52    75.000000            maruti                           swift ldi    0
# 53    74.000000            maruti                           swift vdi    0
# 54    82.000000           hyundai                          i10 sportz    0
# 55   103.200000        volkswagen              vento  1.6 comfortline    0
# 56    53.300000           renault                            kwid rxt    0
# 57    78.900000           hyundai                            i10 asta    0
# 58   147.600000            nissan                         x-trail slx    0
# 59    67.100000            maruti                      zen-estilo vxi    0
# 60   147.800000            toyota             innova-crysta 2.4 gx 8s    0
# 61    68.000000              ford                      figo  titanium    0
# 62   186.000000     mercedes-benz    new c-class c 200 cgi avantgarde    0
# 63   170.000000     mercedes-benz         new c-class 200 cdi classic    0
# 64    69.000000              tata                       indica v2 els    0
# 65   140.000000              audi              a4 2.0 tdi multitronic    0
# 66    78.000000             honda                         city zx cvt    0
# 67   194.000000     mercedes-benz          c-class progressive c 220d    0
# 68    88.500000            maruti                     ertiga shvs vdi    0
# 69    88.700000           hyundai                    creta 1.4 e plus    0
# 70   500.000000           porsche                      cayenne  turbo    0
# 71   140.000000          mahindra                       xuv500 w8 4wd    0
# 72    78.900000           hyundai                      i10 sportz 1.2    0
# 73   108.500000            nissan                    terrano xv d pre    0
# 74    86.800000             honda                             brio vx    0
# 75   187.740000              audi           a6 2.0 tdi design edition    0
# 76    96.755593              ford                 fiesta 1.4 sxi tdci    0
# 77   132.000000            toyota                       innova 2.0 g1    0
# 78   102.000000            toyota                       innova 2.5 vx    0
# 79    92.229726           hyundai                      santro-xing xl    0
# 80    74.000000            maruti                           swift vdi    0
# 81    88.700000              tata               zest-revotron 1.2t xe    0
# 82    86.700000             honda                     amaze sx i-vtec    0
# 83    68.000000              ford                           figo  zxi    0
# 84    73.940000            maruti                            ritz vdi    0
# 85   117.300000             honda                       city i vtec e    0
# 86   218.000000               bmw                      5 series  525d    0
# 87    78.900000           hyundai                      i10 sportz 1.2    0
# 88    82.000000           hyundai                          i10 sportz    0
# 89    92.229726           hyundai                      santro-xing xo    0
# 90    86.700000             honda                     amaze sx i-vtec    0
# 91   168.500000            toyota                        fortuner 4x2    0
# 92   174.330000              audi                  a6  35 tdi premium    0
# 93    89.840000              ford  ecosport 1.5 dv5 titanium optional    0
# 94   140.000000          mahindra                       xuv500 w8 2wd    0
# 95    98.600000             honda                     amaze sx i-dtec    0
# 96    73.900000        volkswagen                 polo  highline 1.2l    0
# 97   110.000000           hyundai         verna transform sx vgt crdi    0
# 98    67.100000            maruti                         wagon-r vxi    0
# 99   103.500000        volkswagen                 polo  highline 1.6l    0
#
#     BS_Version  Model_subName                  Model_specific
# 0            0        wagon-r                             lxi
# 1            0          creta              1.6 crdi sx option
# 2            0           jazz                               v
# 3            0         ertiga                             vdi
# 4            0             a4         new 2.0 tdi multitronic
# 5            0            eon                 era plus option
# 6            0          micra                              xv
# 7            0  innova-crysta                       2.8 gx 8s
# 8            0          vento                     comfortline
# 9            0         indica              vista quadrajet ls
# 10           0           ciaz                            zeta
# 11           0           city                   1.5 v sunroof
# 12           4          swift                             vdi
# 13           0    range-rover                       2.2l pure
# 14           0     freelander                        2 td4 se
# 15           0         pajero                       sport 4x4
# 16           0          amaze                       s i-dtech
# 17           0          swift                        ddis vdi
# 18           0         duster                  85ps  rxl plus
# 19           0            new  c-class c 220 cdi be avantgare
# 20           0              3                     series 320d
# 21           0        s-cross                  ddis 200 alpha
# 22           0             a6              35 tfsi technology
# 23           0            i20                       1.2 magna
# 24           0          vento                        highline
# 25           0           city               corporate edition
# 26           0          micra                              xv
# 27           0       alto-k10                             vxi
# 28           0            wrv                       i-vtec vx
# 29           0         innova                           2.5 v
# 30           0         duster                 110ps  rxz pack
# 31           0        corolla                         altis g
# 32           0      ssangyong                      rexton rx7
# 33           0             a6                         2.7 tdi
# 34           0          vento                    1.6 highline
# 35           3        wagon-r                             lxi
# 36           0  vitara-brezza                        zdi plus
# 37           0        kuv-100              mfalcon g80 k6  aw
# 38           0        m-class                      ml 350 cdi
# 39           0           polo                  trendline 1.2l
# 40           0           alto                             lxi
# 41           0           nano                           lx se
# 42           0        kuv-100        mfalcon d75 k8 dual tone
# 43           0            i20              magna optional 1.2
# 44           0        elantra                   2.0 sx option
# 45           0        corolla                         altis g
# 46           0        elantra                            crdi
# 47           0  innova-crysta                          2.7 gx
# 48           0          xcent                      1.1 crdi s
# 49           0           thar                         crde ac
# 50           0             a4    2.0 tdi 177 bhp premium plus
# 51           0          swift                             ldi
# 52           4          swift                             ldi
# 53           0          swift                             vdi
# 54           0            i10                          sportz
# 55           0          vento                 1.6 comfortline
# 56           0           kwid                             rxt
# 57           0            i10                            asta
# 58           0        x-trail                             slx
# 59           3     zen-estilo                             vxi
# 60           0  innova-crysta                       2.4 gx 8s
# 61           0           figo                        titanium
# 62           0            new    c-class c 200 cgi avantgarde
# 63           0            new         c-class 200 cdi classic
# 64           0         indica                          v2 els
# 65           0             a4             2.0 tdi multitronic
# 66           0           city                          zx cvt
# 67           0        c-class              progressive c 220d
# 68           0         ertiga                        shvs vdi
# 69           0          creta                      1.4 e plus
# 70           0        cayenne                           turbo
# 71           0         xuv500                          w8 4wd
# 72           0            i10                      sportz 1.2
# 73           0        terrano                        xv d pre
# 74           0           brio                              vx
# 75           0             a6          2.0 tdi design edition
# 76           0         fiesta                    1.4 sxi tdci
# 77           0         innova                          2.0 g1
# 78           4         innova                          2.5 vx
# 79           0    santro-xing                              xl
# 80           0          swift                             vdi
# 81           0  zest-revotron                         1.2t xe
# 82           0          amaze                       sx i-vtec
# 83           0           figo                             zxi
# 84           0           ritz                             vdi
# 85           0           city                        i vtec e
# 86           0              5                    series  525d
# 87           0            i10                      sportz 1.2
# 88           0            i10                          sportz
# 89           0    santro-xing                              xo
# 90           0          amaze                       sx i-vtec
# 91           0       fortuner                             4x2
# 92           0             a6                  35 tdi premium
# 93           0       ecosport       1.5 dv5 titanium optional
# 94           0         xuv500                          w8 2wd
# 95           0          amaze                       sx i-dtec
# 96           0           polo                   highline 1.2l
# 97           0          verna           transform sx vgt crdi
# 98           4        wagon-r                             vxi
# 99           0           polo                   highline 1.6l

# %%
Model_specific = " ".join(df['Model_specific'].str.strip().tolist())

# %%
Model_specific = Model_specific.split(' ')

# %%
Model_specific
# Out:
# ['lxi',
#  '1.6',
#  'crdi',
#  'sx',
#  'option',
#  'v',
#  'vdi',
#  'new',
#  '2.0',
#  'tdi',
#  'multitronic',
#  'era',
#  'plus',
#  'option',
#  'xv',
#  '2.8',
#  'gx',
#  '8s',
#  'comfortline',
#  'vista',
#  'quadrajet',
#  'ls',
#  'zeta',
#  '1.5',
#  'v',
#  'sunroof',
#  'vdi',
#  '2.2l',
#  'pure',
#  '2',
#  'td4',
#  'se',
#  'sport',
#  '4x4',
#  's',
#  'i-dtech',
#  'ddis',
#  'vdi',
#  '85ps',
#  '',
#  'rxl',
#  'plus',
#  'c-class',
#  'c',
#  '220',
#  'cdi',
#  'be',
#  'avantgare',
#  'series',
#  '320d',
#  'ddis',
#  '200',
#  'alpha',
#  '35',
#  'tfsi',
#  'technology',
#  '1.2',
#  'magna',
#  'highline',
#  'corporate',
#  'edition',
#  'xv',
#  'vxi',
#  'i-vtec',
#  'vx',
#  '2.5',
#  'v',
#  '110ps',
#  '',
#  'rxz',
#  'pack',
#  'altis',
#  'g',
#  'rexton',
#  'rx7',
#  '2.7',
#  'tdi',
#  '1.6',
#  'highline',
#  'lxi',
#  'zdi',
#  'plus',
#  'mfalcon',
#  'g80',
#  'k6',
#  '',
#  'aw',
#  'ml',
#  '350',
#  'cdi',
#  'trendline',
#  '1.2l',
#  'lxi',
#  'lx',
#  'se',
#  'mfalcon',
#  'd75',
#  'k8',
#  'dual',
#  'tone',
#  'magna',
#  'optional',
#  '1.2',
#  '2.0',
#  'sx',
#  'option',
#  'altis',
#  'g',
#  'crdi',
#  '2.7',
#  'gx',
#  '1.1',
#  'crdi',
#  's',
#  'crde',
#  'ac',
#  '2.0',
#  'tdi',
#  '177',
#  'bhp',
#  'premium',
#  'plus',
#  'ldi',
#  'ldi',
#  'vdi',
#  'sportz',
#  '1.6',
#  'comfortline',
#  'rxt',
#  'asta',
#  'slx',
#  'vxi',
#  '2.4',
#  'gx',
#  '8s',
#  'titanium',
#  'c-class',
#  'c',
#  '200',
#  'cgi',
#  'avantgarde',
#  'c-class',
#  '200',
#  'cdi',
#  'classic',
#  'v2',
#  'els',
#  '2.0',
#  'tdi',
#  'multitronic',
#  'zx',
#  'cvt',
#  'progressive',
#  'c',
#  '220d',
#  'shvs',
#  'vdi',
#  '1.4',
#  'e',
#  'plus',
#  'turbo',
#  'w8',
#  '4wd',
#  'sportz',
#  '1.2',
#  'xv',
#  'd',
#  'pre',
#  'vx',
#  '2.0',
#  'tdi',
#  'design',
#  'edition',
#  '1.4',
#  'sxi',
#  'tdci',
#  '2.0',
#  'g1',
#  '2.5',
#  'vx',
#  'xl',
#  'vdi',
#  '1.2t',
#  'xe',
#  'sx',
#  'i-vtec',
#  'zxi',
#  'vdi',
#  'i',
#  'vtec',
#  'e',
#  'series',
#  '',
#  '525d',
#  'sportz',
#  '1.2',
#  'sportz',
#  'xo',
#  'sx',
#  'i-vtec',
#  '4x2',
#  '35',
#  'tdi',
#  'premium',
#  '1.5',
#  'dv5',
#  'titanium',
#  'optional',
#  'w8',
#  '2wd',
#  'sx',
#  'i-dtec',
#  'highline',
#  '1.2l',
#  'transform',
#  'sx',
#  'vgt',
#  'crdi',
#  'vxi',
#  'highline',
#  '1.6l',
#  '1.4',
#  'crdi',
#  'sportz',
#  'asta',
#  '1.2',
#  'plus',
#  't',
#  '3.0',
#  'tdi',
#  'quattro',
#  'premium',
#  'asta',
#  'std',
#  'liva',
#  '1.2',
#  'g',
#  '3.0',
#  'litre',
#  's',
#  'premium',
#  'luxury',
#  'w8',
#  '2wd',
#  '1.6',
#  'sx',
#  'crdi',
#  '(o)',
#  '2.8',
#  'zx',
#  'ac',
#  'twist',
#  'xt',
#  'series',
#  '320d',
#  'luxury',
#  'line',
#  '1.8',
#  'v',
#  '2.5',
#  'vx',
#  '()',
#  'cross',
#  'country',
#  'd3',
#  'xv',
#  'cvt',
#  'series',
#  '',
#  '525i',
#  'vdi',
#  'xl',
#  'erlx',
#  'euro',
#  'iii',
#  'class',
#  'b200',
#  'cdi',
#  'crdi',
#  '1.6',
#  'sx',
#  'option',
#  'lxi',
#  'xta',
#  'vlx',
#  'c-class',
#  '200',
#  'k',
#  'lxi',
#  '2.4',
#  '1.5',
#  'tdi',
#  'comfortline',
#  'vxi',
#  'plus',
#  'w10',
#  'fwd',
#  'vxi',
#  'vxi',
#  '43',
#  'amg',
#  'vtvt',
#  '1.6',
#  'sx',
#  'plus',
#  'lxi',
#  'series',
#  '118d',
#  'base',
#  '1.2',
#  'v',
#  'cvt',
#  'i',
#  'vtec',
#  '1.8',
#  'v',
#  'c-class',
#  'c',
#  '220',
#  'cdi',
#  'avantgarde',
#  'sx',
#  'i-dtec',
#  'vvt',
#  'vxi',
#  'xo',
#  'erlx',
#  'euro',
#  'ii',
#  '3.0',
#  'lt',
#  'option',
#  '1.5',
#  'tdi',
#  'elegance',
#  '1.4',
#  'alpha',
#  'coupe',
#  'series',
#  'luxury',
#  'line',
#  '2.0',
#  'tdi',
#  '177',
#  'bhp',
#  'premium',
#  'plus',
#  'vdi',
#  'class',
#  '',
#  's',
#  '500',
#  '1.5',
#  'tdi',
#  'elegance',
#  'plus',
#  'black',
#  'package',
#  'elegance',
#  '2.0',
#  'tdi',
#  'cr',
#  'magna',
#  'plus',
#  'trendline',
#  '1.2l',
#  'nxt',
#  's',
#  'class',
#  'b180',
#  'i',
#  'dtec',
#  'v',
#  '2.5',
#  'g',
#  '()',
#  'vxi',
#  'optional',
#  'w8',
#  '2wd',
#  '1.5',
#  'dv5',
#  'ambiente',
#  '4x2',
#  '1.5',
#  'highline',
#  'plus',
#  '16',
#  'alloy',
#  'titanium',
#  'xdrive',
#  '30d',
#  'c-class',
#  'c',
#  '220',
#  'cdi',
#  'style',
#  'v',
#  'magna',
#  '1.2',
#  '220',
#  '1.2',
#  'kappa',
#  'asta',
#  '2.0',
#  'tdi',
#  'premium',
#  'plus',
#  'highline',
#  'd',
#  'asta',
#  '1.4',
#  'crdi',
#  '2.0',
#  'tdi',
#  'premium',
#  'plus',
#  'lt',
#  'elegance',
#  '1.8',
#  'tsi',
#  '1.4',
#  'tdci',
#  'exi',
#  'limited',
#  'edition',
#  'series',
#  '520d',
#  'luxury',
#  'line',
#  'magnum',
#  '1.6',
#  'ls',
#  'highline',
#  '1.2l',
#  '110ps',
#  'rxz',
#  'e250',
#  'cdi',
#  'avantgrade',
#  'alpha',
#  '1.6',
#  'sx',
#  'magna',
#  '1.1',
#  '1.99',
#  's10',
#  '4wd',
#  '2.2l',
#  'dynamic',
#  'zxi',
#  'zdi',
#  '1.5',
#  'gxi',
#  's',
#  'i-dtech',
#  'magna',
#  's',
#  'i-dtech',
#  'ambiente',
#  '85ps',
#  '',
#  'rxl',
#  'n6',
#  'zdi',
#  'plus',
#  'dual',
#  'tone',
#  'asta',
#  'option',
#  '1.2',
#  '1.4',
#  'mpi',
#  'ambiente',
#  'ecs',
#  'glx',
#  '35',
#  'tdi',
#  'quattro',
#  'premium',
#  'plus',
#  'elegance',
#  '1.8',
#  'tsi',
#  'liva',
#  'gd',
#  'sp',
#  '1.3',
#  'vxi',
#  'class',
#  'b180',
#  's',
#  '1.6',
#  'sx',
#  '85ps',
#  '',
#  'rxl',
#  'optional',
#  '1.6',
#  'vtvt',
#  's',
#  'vxi',
#  'c-class',
#  'c250',
#  'avantgarde',
#  'l',
#  '3.0',
#  'tdi',
#  'quattro',
#  'magna',
#  '1.1',
#  '1.6',
#  'mpi',
#  'style',
#  'black',
#  'package',
#  'style',
#  '1.8',
#  'tsi',
#  'active',
#  '1.2',
#  'sx',
#  'vx',
#  'i-dtec',
#  'lxi',
#  '1.5',
#  'd4',
#  'c-class',
#  'c',
#  '220d',
#  'avantgarde',
#  'edition',
#  'c',
#  'vxi',
#  'xv',
#  'premium',
#  '110',
#  'ps',
#  'anniversary',
#  'edition',
#  'vdi',
#  's',
#  'std',
#  'v2',
#  'dls',
#  'lt',
#  'comfortline',
#  '1.2l',
#  'zdi',
#  'exi',
#  '2.8',
#  'gx',
#  'fe',
#  '4x4',
#  'i-vtec',
#  'v',
#  '1.2',
#  'magna',
#  'executive',
#  'c-class',
#  'c',
#  '220d',
#  'avantgarde',
#  'edition',
#  'c',
#  'lt',
#  'sportz',
#  '1.4',
#  'crdi',
#  '2.5',
#  'z',
#  'vdi',
#  '2.5',
#  'v',
#  'xo',
#  'erlx',
#  'euro',
#  'ii',
#  'i',
#  'vtec',
#  'v',
#  'sdrive20d',
#  'crdi',
#  'era',
#  '1.3',
#  'alpha',
#  'leisure',
#  '1.6',
#  'tdi',
#  'crdi',
#  'gt',
#  '1.5',
#  'tdi',
#  '1.2',
#  'vx',
#  'i',
#  'vtec',
#  'era',
#  '2.0',
#  'e-vgt',
#  '2wd',
#  'gls',
#  '2.4',
#  'zx',
#  'mpi',
#  'cargo',
#  'w/',
#  'immobiliser',
#  'vxi',
#  'magna',
#  'vdi',
#  'crdi',
#  '1.6',
#  'sx',
#  'xl',
#  '1.2',
#  'sportz',
#  '350d',
#  'c-class',
#  'c',
#  '220',
#  'cdi',
#  'classic',
#  'zdi',
#  '1.6',
#  'crdi',
#  'sx',
#  'vxi',
#  '110ps',
#  '',
#  'rxz',
#  'option',
#  '1.3',
#  'emotion',
#  'pack',
#  '()',
#  'xdrive30d',
#  'm',
#  'sport',
#  'sportz',
#  '2.5',
#  'g4',
#  'vxi',
#  'vdi',
#  'vlx',
#  '2.2',
#  'mhawk',
#  'airbag',
#  '1.3',
#  '75ps',
#  'xe',
#  '1.0',
#  'ecoboost',
#  'titanium',
#  'plus',
#  'dzire',
#  'zdi',
#  'lxi',
#  '1.5',
#  's',
#  '3.0',
#  'tdi',
#  'quattro',
#  'technology',
#  '1.9',
#  'tdi',
#  'ambiente',
#  '1.6',
#  'sx',
#  'vtvt',
#  '(o)',
#  '1.5',
#  'v',
#  'magna',
#  'optional',
#  '1.4',
#  'crdi',
#  'sportz',
#  '1.4',
#  'highline',
#  'i',
#  'vtec',
#  'vx',
#  '1.3',
#  '75ps',
#  'xe',
#  'series',
#  '',
#  '520d',
#  'lxi',
#  'minor',
#  'vx',
#  '2.0',
#  'tdi',
#  'comfortline',
#  'magna',
#  '1.2',
#  'c-class',
#  'c',
#  '220',
#  'cdi',
#  'avantgarde',
#  'magna',
#  '1.2',
#  'itech',
#  'se',
#  '2.4',
#  'zx',
#  '2.0',
#  'tdi',
#  'technology',
#  '2.5',
#  'vx',
#  '()',
#  'trendline',
#  '1.2l',
#  'lxi',
#  'i-vtec',
#  'cvt',
#  'zx',
#  'lx',
#  '2.0',
#  'tdi',
#  'premium',
#  'plus',
#  'class',
#  '200',
#  'cdi',
#  'sport',
#  'xl',
#  'vdi',
#  'vxi',
#  '250d',
#  'hse',
#  'dynamic',
#  'trendline',
#  'std',
#  '1.2',
#  'vx',
#  'delux',
#  'vista',
#  'aura',
#  '1.3',
#  'quadrajet',
#  'lxi',
#  'w8',
#  '4wd',
#  'ls',
#  'dicor',
#  'paseo',
#  'vxi',
#  '2.4',
#  'a/t',
#  'dzire',
#  'vdi',
#  'exi',
#  '1.4',
#  'tdci',
#  'ltd',
#  'zx',
#  'gxi',
#  '2.0',
#  'tdi',
#  'premium',
#  'plus',
#  'series',
#  '640d',
#  'gran',
#  'coupe',
#  '45',
#  'tdi',
#  'quattro',
#  'technology',
#  'lxi',
#  'green',
#  '()',
#  '1.4',
#  'crdi',
#  'asta',
#  'sportz',
#  '1.2',
#  'v',
#  'cvt',
#  'i',
#  'vtec',
#  'vdi',
#  'asta',
#  '1.2',
#  'comfortline',
#  '1.2l',
#  'lxi',
#  'h4',
#  'lxi',
#  'elan',
#  'quadrajet',
#  'lxi',
#  'ambition',
#  'plus',
#  '2.0',
#  'tdi',
#  'h4',
#  'asta',
#  'option',
#  '1.2',
#  'ldi',
#  '1.5',
#  'v',
#  'vista',
#  'aqua',
#  '1.3',
#  'quadrajet',
#  's',
#  'i-dtech',
#  'd',
#  'lite',
#  'plus',
#  'series',
#  'luxury',
#  'line',
#  '1.6',
#  'sx',
#  'club',
#  'class',
#  'quadrajet90',
#  'ls',
#  'rs',
#  'vxi',
#  '1.5',
#  'dv5',
#  'titanium',
#  'optional',
#  '1.0',
#  'ls',
#  '2.0',
#  '',
#  'portfolio',
#  'rvi',
#  'l&k',
#  '1.8',
#  'tsi',
#  'magna',
#  '1.2',
#  'ldi',
#  'dzire',
#  'vxi',
#  'xv',
#  'dzire',
#  'tour',
#  'ldi',
#  'classic',
#  '1.4',
#  'duratorq',
#  'clxi',
#  'lx',
#  's',
#  'gd',
#  'lxi',
#  'vxi',
#  '3.0d',
#  'xv',
#  'asta',
#  'zdi',
#  'plus',
#  '3.0',
#  'tdi',
#  'quattro',
#  'premium',
#  'plus',
#  'class',
#  '200',
#  'cdi',
#  'ac',
#  '85ps',
#  '',
#  'rxl',
#  'altis',
#  'd-4d',
#  'gl',
#  'c-class',
#  '220',
#  'vdi',
#  'i-vtec',
#  'v',
#  'cvt',
#  '1.1',
#  'crdi',
#  'base',
#  'e250',
#  'cdi',
#  'avantgarde',
#  'class',
#  'b180',
#  'e250',
#  'edition',
#  'e',
#  'i',
#  'vtec',
#  'vx',
#  'option',
#  'xl',
#  'erlx',
#  'euro',
#  'iii',
#  '1.5',
#  's',
#  'transform',
#  'vtvt',
#  'portfolio',
#  's',
#  'i-vtech',
#  '1.6',
#  'class',
#  '',
#  's',
#  '350',
#  'cdi',
#  'magna',
#  'plus',
#  'vxi',
#  'ldi',
#  'series',
#  '320d',
#  'sedan',
#  'xt',
#  'ex',
#  '4x2',
#  '35',
#  'tditraction',
#  '2.2l',
#  'dynamic',
#  '350',
#  'cdi',
#  'luxury',
#  'sport',
#  '4x2',
#  'dualtone',
#  'blacktop',
#  'lx',
#  'lxi',
#  '2.2l',
#  'prestige',
#  '1.6',
#  'sx',
#  'vtvt',
#  'series',
#  '525d',
#  'sedan',
#  'std',
#  'elegance',
#  '1.8',
#  'tsi',
#  '35',
#  'tdi',
#  'quattro',
#  'premium',
#  '2.2l',
#  'pure',
#  'c-class',
#  '220',
#  'cdi',
#  's10',
#  '4wd',
#  'series',
#  'luxury',
#  'line',
#  'i-vtec',
#  's',
#  'd5',
#  'gle',
#  'active',
#  'sx',
#  '43',
#  'amg',
#  'coupe',
#  'magna',
#  'plus',
#  'sportz',
#  'edition',
#  '1.5',
#  'exi',
#  's',
#  'trendline',
#  '1.2l',
#  '35',
#  'tfsi',
#  'matrix',
#  '1.9',
#  'l',
#  'tdi',
#  '1.6',
#  'sx',
#  'plus',
#  'dual',
#  'tone',
#  'c-class',
#  'c',
#  '200',
#  'cgi',
#  'avantgarde',
#  's',
#  ...]

# %%
df[df['Model_Name'].str.contains('mt')].head(100)
# Out:
# Empty DataFrame
# Columns: [Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Seats, Price, Mileage_Value, Mileage_Unit, Engine_Value, Power_Value, Manufacturer_Name, Model_Name, ABS, BS_Version, Model_subName, Model_specific]
# Index: []

# %%
df['Model_Name'].unique().tolist()
# Out:
# ['wagon-r lxi',
#  'creta 1.6 crdi sx option',
#  'jazz v',
#  'ertiga vdi',
#  'a4 new 2.0 tdi multitronic',
#  'eon  era plus option',
#  'micra  xv',
#  'innova-crysta 2.8 gx 8s',
#  'vento  comfortline',
#  'indica vista quadrajet ls',
#  'ciaz zeta',
#  'city 1.5 v sunroof',
#  'swift vdi',
#  'range-rover 2.2l pure',
#  'freelander 2 td4 se',
#  'pajero sport 4x4',
#  'amaze s i-dtech',
#  'swift ddis vdi',
#  'duster 85ps  rxl plus',
#  'new c-class c 220 cdi be avantgare',
#  '3 series 320d',
#  's-cross ddis 200 alpha',
#  'a6  35 tfsi technology',
#  'i20 1.2 magna',
#  'vento  highline',
#  'city corporate edition',
#  'alto-k10  vxi',
#  'wrv i-vtec vx',
#  'innova 2.5 v',
#  'duster 110ps  rxz pack',
#  'corolla altis g',
#  'ssangyong rexton rx7',
#  'a6 2.7 tdi',
#  'vento 1.6 highline',
#  'vitara-brezza zdi plus',
#  'kuv-100 mfalcon g80 k6  aw',
#  'm-class ml 350 cdi',
#  'polo  trendline 1.2l',
#  'alto lxi',
#  'nano lx se',
#  'kuv-100 mfalcon d75 k8 dual tone',
#  'i20 magna optional 1.2',
#  'elantra 2.0 sx option',
#  'elantra crdi',
#  'innova-crysta 2.7 gx',
#  'xcent 1.1 crdi s',
#  'thar crde ac',
#  'a4 2.0 tdi 177 bhp premium plus',
#  'swift ldi',
#  'i10 sportz',
#  'vento  1.6 comfortline',
#  'kwid rxt',
#  'i10 asta',
#  'x-trail slx',
#  'zen-estilo vxi',
#  'innova-crysta 2.4 gx 8s',
#  'figo  titanium',
#  'new c-class c 200 cgi avantgarde',
#  'new c-class 200 cdi classic',
#  'indica v2 els',
#  'a4 2.0 tdi multitronic',
#  'city zx cvt',
#  'c-class progressive c 220d',
#  'ertiga shvs vdi',
#  'creta 1.4 e plus',
#  'cayenne  turbo',
#  'xuv500 w8 4wd',
#  'i10 sportz 1.2',
#  'terrano xv d pre',
#  'brio vx',
#  'a6 2.0 tdi design edition',
#  'fiesta 1.4 sxi tdci',
#  'innova 2.0 g1',
#  'innova 2.5 vx',
#  'santro-xing xl',
#  'zest-revotron 1.2t xe',
#  'amaze sx i-vtec',
#  'figo  zxi',
#  'ritz vdi',
#  'city i vtec e',
#  '5 series  525d',
#  'santro-xing xo',
#  'fortuner 4x2',
#  'a6  35 tdi premium',
#  'ecosport 1.5 dv5 titanium optional',
#  'xuv500 w8 2wd',
#  'amaze sx i-dtec',
#  'polo  highline 1.2l',
#  'verna transform sx vgt crdi',
#  'wagon-r vxi',
#  'polo  highline 1.6l',
#  'i20 1.4 crdi sportz',
#  'i20 asta 1.2',
#  'go plus t',
#  'a4 3.0 tdi quattro premium',
#  'i20  asta',
#  'omni  std',
#  'etios liva 1.2 g',
#  'xf 3.0 litre s premium luxury',
#  'verna 1.6 sx crdi (o)',
#  'innova-crysta 2.8 zx',
#  'eeco  ac',
#  'nano twist xt',
#  '3 series 320d luxury line',
#  'civic  1.8 v',
#  'innova 2.5 vx ()',
#  'v40 cross country d3',
#  'micra xv cvt',
#  '5 series  525i',
#  'vitara-brezza vdi',
#  'santro-xing xl erlx euro iii',
#  'b class b200 cdi',
#  'verna crdi 1.6 sx option',
#  'nano xta',
#  'scorpio vlx',
#  'new c-class 200 k',
#  'cr-v 2.4',
#  'vento 1.5 tdi comfortline',
#  'ciaz vxi plus',
#  'xuv500 w10 fwd',
#  'ritz vxi',
#  'alto-k10 vxi',
#  'slc 43 amg',
#  'verna vtvt 1.6 sx plus',
#  '1 series 118d base',
#  'jazz 1.2 v cvt i vtec',
#  'new c-class c 220 cdi avantgarde',
#  'swift vvt vxi',
#  'santro-xing xo erlx euro ii',
#  'fortuner 3.0',
#  'beat lt option',
#  'rapid 1.5 tdi elegance',
#  'ciaz 1.4 alpha',
#  'rs5 coupe',
#  '3 series luxury line',
#  's class  s 500',
#  'rapid 1.5 tdi elegance plus black package',
#  'superb elegance 2.0 tdi cr',
#  'eon magna plus',
#  'go nxt',
#  'brio s',
#  'b class b180',
#  'city i dtec v',
#  'innova 2.5 g ()',
#  'swift vxi optional',
#  'ecosport 1.5 dv5 ambiente',
#  'vento 1.5 highline plus 16 alloy',
#  'x5 xdrive 30d',
#  'new c-class c 220 cdi style',
#  'brio v',
#  'i10 magna 1.2',
#  'glc 220',
#  'i10 1.2 kappa asta',
#  'a6  2.0 tdi premium plus',
#  'countryman  d',
#  'i20 asta 1.4 crdi',
#  'beat  lt',
#  'superb elegance 1.8 tsi',
#  'fiesta 1.4 tdci exi limited edition',
#  '5 series 520d luxury line',
#  'optra magnum 1.6 ls',
#  'lodgy 110ps rxz',
#  'e-class e250 cdi avantgrade',
#  'baleno alpha',
#  'verna 1.6 sx',
#  'i10 magna 1.1',
#  'scorpio 1.99 s10 4wd',
#  'range-rover 2.2l dynamic',
#  'ertiga zdi',
#  'city 1.5 gxi',
#  'i10 magna',
#  'laura ambiente',
#  'duster 85ps  rxl',
#  'nuvosport n6',
#  'vitara-brezza zdi plus dual tone',
#  'i20 asta option 1.2',
#  'fabia 1.4 mpi ambiente',
#  'indigo ecs glx',
#  'q3  35 tdi quattro premium plus',
#  'octavia elegance 1.8 tsi',
#  'etios liva gd sp',
#  'swift 1.3 vxi',
#  'amaze s',
#  'duster 85ps  rxl optional',
#  'creta 1.6 vtvt s',
#  'new c-class c250 avantgarde',
#  'a8 l 3.0 tdi quattro',
#  'rapid 1.6 mpi style black package',
#  'superb style 1.8 tsi',
#  'i20 active 1.2 sx',
#  'amaze vx i-dtec',
#  'verito 1.5 d4',
#  'new c-class c 220d avantgarde edition c',
#  'terrano xv premium 110 ps anniversary edition',
#  'convertible s',
#  'figo',
#  'indica v2 dls',
#  'beat lt',
#  'polo  comfortline 1.2l',
#  'swift zdi',
#  'figo  exi',
#  'innova-crysta 2.8 gx',
#  'santa fe 4x4',
#  'city i-vtec v',
#  'i20 1.2 magna executive',
#  'i20 sportz 1.4 crdi',
#  'innova 2.5 z',
#  'city i vtec v',
#  'x1 sdrive20d',
#  'i10 crdi era',
#  'ciaz 1.3 alpha',
#  'rapid leisure 1.6 tdi',
#  'accent crdi',
#  'polo gt 1.5 tdi',
#  'jazz 1.2 vx i vtec',
#  'i10 era',
#  'tucson 2.0 e-vgt 2wd gls',
#  'innova-crysta 2.4 zx',
#  'omni mpi cargo w/ immobiliser',
#  'swift vxi',
#  'verna crdi 1.6 sx',
#  'i20 1.2 sportz',
#  'gle 350d',
#  'new c-class c 220 cdi classic',
#  'ritz zdi',
#  'creta 1.6 crdi sx',
#  'a-star vxi',
#  'duster 110ps  rxz option',
#  'grande-punto 1.3 emotion pack ()',
#  'x3 xdrive30d m sport',
#  'innova 2.5 g4',
#  'zen vxi',
#  'scorpio vlx 2.2 mhawk airbag',
#  'zest-quadrajet 1.3 75ps xe',
#  'ecosport 1.0 ecoboost titanium plus',
#  'swift dzire zdi',
#  'city 1.5 s',
#  'q7 3.0 tdi quattro technology',
#  'laura 1.9 tdi ambiente',
#  'verna 1.6 sx vtvt (o)',
#  'city 1.5 v',
#  'i20 magna optional 1.4 crdi',
#  'i20 sportz 1.4',
#  'city i vtec vx',
#  '5 series  520d',
#  'wagon-r lxi minor',
#  'jazz vx',
#  'jetta  2.0 tdi comfortline',
#  'i10 magna 1.2 itech se',
#  'a6  2.0 tdi technology',
#  'alto-k10 lxi',
#  'city i-vtec cvt zx',
#  'indigo lx',
#  'gla class 200 cdi sport',
#  'celerio vxi',
#  'gle 250d',
#  'range-rover hse dynamic',
#  'vento  trendline',
#  'omni',
#  'brio 1.2 vx',
#  'sumo delux',
#  'indica vista aura 1.3 quadrajet',
#  'indigo ls dicor',
#  'ertiga paseo vxi',
#  'accord 2.4 a/t',
#  'swift dzire vdi',
#  'fiesta exi 1.4 tdci ltd',
#  'city zx gxi',
#  '6 series 640d gran coupe',
#  'q7 45 tdi quattro technology',
#  'zen-estilo lxi green ()',
#  'i20 1.4 crdi asta',
#  'corolla h4',
#  'manza elan quadrajet',
#  'octavia ambition plus 2.0 tdi',
#  'vitara-brezza ldi',
#  'indica vista aqua 1.3 quadrajet',
#  'eon d lite plus',
#  'manza club class quadrajet90 ls',
#  'octavia rs',
#  'spark 1.0 ls',
#  'xf 2.0  portfolio',
#  'cr-v rvi',
#  'superb l&k 1.8 tsi',
#  'swift dzire vxi',
#  'swift dzire tour ldi',
#  'fiesta classic 1.4 duratorq clxi',
#  'zen lx',
#  'clubman  s',
#  'etios gd',
#  'alto  lxi',
#  'alto vxi',
#  'x5 3.0d',
#  'teana xv',
#  'q7 3.0 tdi quattro premium plus',
#  'gla class 200 cdi',
#  '800 ac',
#  'corolla altis d-4d gl',
#  'new c-class 220',
#  'brv i-vtec v cvt',
#  'xcent 1.1 crdi base',
#  'e-class  e250 cdi avantgarde',
#  'e-class  e250 edition e',
#  'city i vtec vx option',
#  'verna transform vtvt',
#  'xe portfolio',
#  'amaze s i-vtech',
#  'convertible 1.6',
#  's class  s 350 cdi',
#  'ritz ldi',
#  '3 series 320d sedan',
#  'xenon xt ex 4x2',
#  'a3 35 tditraction',
#  'gl-class  350 cdi luxury',
#  'pajero sport 4x2 dualtone blacktop',
#  'alto lx',
#  'range-rover 2.2l prestige',
#  'verna 1.6 sx vtvt',
#  '5 series 525d sedan',
#  'xf',
#  'q3 35 tdi quattro premium',
#  'new c-class 220 cdi',
#  'scorpio s10 4wd',
#  'br-v i-vtec s',
#  's80  d5',
#  'accent gle',
#  'i20 active sx',
#  'glc 43 amg coupe',
#  'i10 sportz edition',
#  'city 1.5 exi s',
#  'a6 35 tfsi matrix',
#  'jetta  1.9 l tdi',
#  'creta 1.6 sx plus dual tone',
#  'etios vd',
#  'laura ambiente 2.0 tdi cr',
#  'eon era plus',
#  'captur 1.5  rxl',
#  '5 series  gt 530d le',
#  'v40 d3',
#  'eeco  with ac plus htr',
#  'enjoy 1.4 ls 8',
#  'bolero zlx',
#  'santro gls i - euro i',
#  'eon d lite',
#  'creta 1.6 sx plus',
#  'vento 1.6 comfortline',
#  'civic  1.8 s',
#  'i20 1.2 asta option',
#  'q5 30 tdi quattro premium plus',
#  'cedia sports',
#  'celerio ldi',
#  's-cross delta ddis 200 sh',
#  'q3 35 tdi quattro premium plus',
#  'q7 4.2 tdi quattro technology',
#  'i20  asta 1.2',
#  'duster 110ps  rxl',
#  'xcent 1.1 crdi s celebration edition',
#  'ecosport 1.5 dv5 titanium',
#  'i10 crdi magna',
#  'manza aqua quadrajet',
#  'santro-xing gls',
#  'ciaz 1.3 s',
#  'fortuner 4x4 trd sportivo',
#  'fiesta 1.6 sxi  duratec',
#  'e-class e 220 d',
#  'yeti ambition 4x2',
#  'figo  1.2p titanium',
#  'octavia ambition 1.4 tsi',
#  'duster 85ps  rxl option',
#  'range-rover evoque 2.0 td4 pure',
#  'endeavour hurricane limited edition',
#  'fortuner 4x4',
#  'micra  xv premium',
#  '5 series  523i',
#  'gls 350d 4matic',
#  'cr-v 2.4l 4wd',
#  'creta 1.6 crdi sx plus',
#  'a class a200 cdi sport',
#  'ertiga vxi',
#  'octavia classic 1.9 tdi',
#  'amaze vx i-vtech',
#  'zen lxi',
#  'sx4 zxi',
#  'camry a/t',
#  'beat ls',
#  'mobilio s i vtec',
#  'xuv500 w8 fwd',
#  'fabia 1.6 mpi elegance',
#  'scorpio 1.99 s8',
#  'rapid 1.6 tdi ambition',
#  'duster 110ps  rxz',
#  'etios g',
#  'creta 1.6 sx',
#  'a6  35 tdi technology',
#  'e-class 280 cdi',
#  'linea t jet',
#  'ertiga zxi',
#  '3 series 320i sedan',
#  'indigo ls',
#  'e-class  e 250 elegance',
#  'swift dzire ldi',
#  'city i vtec cvt vx',
#  'amaze vx o i vtec',
#  'enjoy tcdi ltz',
#  'new c-class progressive c 200',
#  'sx4 zxi leather',
#  'x1 sdrive 20d xline',
#  'ciaz rs zdi plus shvs',
#  'xuv500 w6 2wd',
#  'etios liva gd',
#  'tt 2.0 tfsi',
#  'rapid 1.5 tdi style',
#  'polo 1.5 tdi highline',
#  'laura 1.9 tdi elegance',
#  'renault logan 1.5 dle',
#  'jazz 1.5 s i dtec',
#  'xf 2.2 litre luxury',
#  'compass 2.0 limited',
#  'corolla altis 1.8 sport',
#  'swift zxi',
#  'ikon 1.3 lxi nxt',
#  'bolero vlx crde',
#  'city i dtec vx option',
#  'sail hatchback 1.2 ls',
#  'i20 1.2 spotz',
#  'x1 sdrive 20d sportline',
#  'x1 sdrive 20d exclusive',
#  's class  s 350 l',
#  'quanto c2',
#  'x5  xdrive 30d design pure experience',
#  'swift ldi optional',
#  'pajero 2.8 sfx dual tone',
#  'xf 2.2 litre executive',
#  'octavia ambition 2.0 tdi',
#  'corolla altis vl',
#  'glc 220d 4matic style',
#  'vento 1.5 tdi highline',
#  'xuv500 w10 2wd',
#  'terrano xl 85 ps',
#  '5 series  530d m sport',
#  'scorpio s4 plus',
#  'verna 1.6 crdi sx',
#  'aveo u-va 1.2 lt',
#  'xcent 1.2 kappa s',
#  'vitara-brezza zdi',
#  '3 series 320d prestige',
#  'eon sportz',
#  'accord 2.4',
#  'xylo e8',
#  'city v',
#  'bolero di',
#  'esteem vxi -',
#  'santro ls zipplus',
#  '5 door d',
#  'i20 sportz option',
#  'safari storme vx varicor 400',
#  'br-v i-dtec vx',
#  'jetta  2.0l tdi highline',
#  'xcent 1.2 kappa s option',
#  'ignis 1.2 alpha',
#  '5 series  520d luxury line',
#  'ikon 1.3 clxi',
#  'verna 1.6 crdi',
#  '3 series 320d highline',
#  'e-class  e200 cgi blue efficiency',
#  'beat option pack',
#  'santro-xing xp',
#  'indica dls',
#  'ciaz zdi plus shvs',
#  'new c-class c 250 cdi avantgarde',
#  'fortuner 4x2 4 speed',
#  'xj 2.0l portfolio',
#  'i20 1.4 magna',
#  'corolla executive (he)',
#  'innova 2.5 zx',
#  'i10 crdi sportz',
#  'vento ipl ii  highline',
#  'verna crdi sx',
#  'city i vtec s',
#  'ciaz zxi',
#  'sunny xv cvt',
#  'new c-class c 220 cdi elegance',
#  'i10 magna optional 1.1l',
#  'ciaz vdi shvs',
#  'ikon 1.3 flair',
#  'polo 1.2 mpi highline',
#  'jazz 1.2 v i vtec',
#  'amaze ex i-dtech',
#  'superb 1.8 tsi',
#  'vitara-brezza ldi option',
#  'i20 asta',
#  'alto-k10 vxi ags',
#  'slk-class slk 350',
#  'ecosport 1.5 tdci titanium',
#  'passat highline dsg',
#  'aveo 1.4',
#  'ritz lxi',
#  'freelander 2 se',
#  'endeavour 3.2 trend 4x4',
#  'q5  2.0 tdi',
#  'verna 1.6 vtvt',
#  'm-class ml 350 4matic',
#  'swift dzire zxi',
#  'city 1.3 exi s',
#  'x5 xdrive 30d design pure experience',
#  'xcent 1.2 kappa sx option',
#  'dzire zxi plus',
#  '3 series 320d corporate edition',
#  's',
#  'terrano xv premium 110 ps',
#  '3 series 320d luxury plus',
#  'yeti elegance 4x2',
#  'ecosport 1.5 ti vct titanium',
#  's-cross ddis 200 sigma option',
#  'i10 1.2 crdi magna',
#  'baleno zeta 1.3',
#  'safari storme  lx',
#  'accent gls',
#  'swift ldi sp limited edition',
#  'jetta  1.9 highline tdi',
#  'range-rover 3.0 d',
#  'city i-vtec cvt vx',
#  'cruze ltz',
#  'nano lx',
#  'figo titanium',
#  'linea emotion',
#  'figo aspire 1.2 ti-vct trend',
#  'baleno lxi',
#  'scorpio 2.6 dx',
#  'innova 2.5 gx ()',
#  'fiesta 1.4 duratorq zxi',
#  'a class a180 cdi',
#  'e-class  e 220 cdi avantgarde',
#  'ecosport 1.5 ti vct titanium be',
#  'koleos 2.0',
#  'omni e  std',
#  'endeavour xlt tdci 4x2',
#  'i20 magna 1.2',
#  'xuv500 w9',
#  'sx4 s-cross ddis 200 zeta',
#  'endeavour 3.2 titanium 4x4',
#  'amaze vx',
#  'mobilio s i dtec',
#  'qualis fs b2',
#  '5 series  530d highline',
#  '3 series 320d m sport',
#  'aveo 1.4 lt',
#  'e-class  e250 cdi elegance',
#  'ameo 1.5 tdi highline',
#  'etios liva g',
#  'i20 1.4 asta',
#  'wagon-r lxi optional',
#  'i20 1.4 asta option',
#  'polo gt tsi',
#  'xylo h4',
#  'alto green lxi ()',
#  'octavia elegance 2.0 tdi',
#  'a6 3.0 tdi quattro',
#  'verna 1.6 crdi ex',
#  'santro-xing gl plus',
#  'a4 2.0 tdi',
#  'cr-v 2.0l 2wd',
#  'mobilio rs i dtec',
#  'bolero vlx',
#  'zen lxi -',
#  'e-class facelift',
#  'xcent 1.2 crdi s',
#  'city i dtec vx',
#  'kwid 1.0 rxt optional',
#  'swift ddis zdi plus',
#  'celerio vxi optional',
#  'dzire vxi',
#  'grand-vitara',
#  'tt 40 tfsi',
#  'new c-class c 200 cgi',
#  'sunny   xv',
#  'accent executive',
#  'scorpio lx 2.6 turbo',
#  'redi-go t option',
#  'camry hybrid',
#  'jetta  2.0l tdi trendline',
#  'a6  2.0 tdi',
#  'eeco  standard',
#  'q5 30 tdi quattro premium',
#  'q3 2.0 tdi',
#  'fortwo cdi',
#  'sumo dx',
#  'indigo ecs elx',
#  'vento tsi',
#  'outlander 2.4',
#  'cayman  s',
#  'fabia 1.2 mpi ambiente',
#  'zen-estilo 1.1 lxi',
#  'ciaz 1.4 delta',
#  'new c-class c 200 avantgarde edition c',
#  'compass 2.0 limited 4x4',
#  'range-rover evoque 2.0 td4 hse dynamic',
#  'ciaz zdi shvs',
#  'sx4 vxi',
#  'elantra crdi sx',
#  'ameo 1.2 mpi comfortline',
#  'kuv-100 mfalcon d75 k6',
#  'baleno delta 1.2',
#  'i20 1.2 asta',
#  'i20 sportz',
#  'xcent 1.2 kappa base',
#  'cla 200 cdi sport',
#  'rapid 1.5 tdi ambition',
#  'accent gls 1.6',
#  'endeavour 2.2 trend 4x2',
#  'beat  ps',
#  'rapid 1.6 mpi ambition plus',
#  'baleno vxi -',
#  'q3  2.0 tdi quattro premium plus',
#  'wagon-r lxi duo',
#  'xc60 d5',
#  'jazz 1.5 vx i dtec',
#  'wagon-r vxi minor',
#  'a class a180 sport',
#  'santro-xing gl',
#  'sunny  xv special edition',
#  'a-star lxi',
#  'kwid rxt optional',
#  '3 series 320d sport line',
#  'indigo cs evx',
#  'omni e mpi std',
#  'ecosport signature edition',
#  'innova-crysta 2.4 gx',
#  'scorpio 2.6 lx',
#  'swift dzire vdi optional',
#  'manza aura safire',
#  'i20 asta (o) 1.4 crdi ()',
#  'beat',
#  'new safari dicor 2.2 ex 4x2',
#  'gl-class 350 cdi blue efficiency',
#  'fortuner 2.8 4wd',
#  'x1 sdrive 18i',
#  'captur 1.5  platine mono',
#  'micra xe',
#  'range-rover tdv8 ()',
#  'compass 1.4 limited option',
#  'a4 35 tdi technology',
#  'i10 asta option',
#  'ecosport 1.5  titanium plus',
#  'indigo gle',
#  's-cross zeta ddis 200 sh',
#  'xuv500 w4 1.99 mhawk',
#  'i10 era 1.1',
#  'new safari dicor 2.2 ex 4x4',
#  'laura elegance',
#  'i20 asta 1.4 crdi ()',
#  'figo  1.5d trend',
#  'boxster s tiptronic',
#  'zest-revotron 1.2 xt',
#  'i20 1.2 sportz option',
#  'fabia 1.4 tdi active',
#  'corolla altis d-4d j',
#  'terrano xl',
#  'xuv300 w8',
#  'hexa xt',
#  '5 series  525d luxury line',
#  'amaze ex i-vtech',
#  'tiago 1.2 revotron xz',
#  'swift lxi',
#  'eon era',
#  'i20 magna 1.4 crdi',
#  'corolla altis  d4dg',
#  'swift vdi w/',
#  '7 series  740li',
#  'superb  elegance 2.0 tdi',
#  'ciaz vdi plus shvs',
#  'avventura multijet emotion',
#  'i10 1.2 kappa magna',
#  'e-class  e 200 cgi avantgarde',
#  'sx4 zdi',
#  'tigor 1.2 revotron xta',
#  'indica gls',
#  'sx4 s-cross ddis 320 zeta',
#  'xcent 1.2 kappa sx',
#  'linea emotion pack ()',
#  'xc60 d5 inscription',
#  'city i dtec s',
#  'verna vtvt 1.6 sx option',
#  'etios gd sp',
#  's60 d4 momentum',
#  'e-class  e350 cdi avantgrade',
#  'innova-crysta 2.4 vx',
#  'polo 1.0 mpi trendline',
#  'freelander 2 hse',
#  'q7 35 tdi quattro premium plus',
#  'city i-vtec s',
#  'cr-v 2.4l 4wd avn',
#  'classic nova',
#  'scorpio vlx 2.2 mhawk',
#  'zen vx',
#  '800 dx',
#  'corolla altis 1.8 vl cvt',
#  '3 series 328i sport line',
#  'corolla altis 1.4 dg',
#  'xuv500 w4',
#  'corolla 1.8 j',
#  'q3 2.0 tdi quattro',
#  'xe 2.0l  prestige',
#  'xylo d4',
#  'camry 2.5 hybrid',
#  'q5 3.0 tdi quattro',
#  'ertiga vdi limited edition',
#  'baleno sigma 1.2',
#  'xcent 1.2 vtvt s',
#  'freelander 2 td4 s',
#  'indigo ecs lx',
#  'alto   lxi',
#  'santro gls i - euro ii',
#  'fortuner 2.8 2wd',
#  'city 1.5 exi',
#  'i10 crdi sportz celebration edition',
#  'figo  lxi',
#  'city 1.3 dx',
#  'ecosport 1.0 ecoboost titanium plus be',
#  'octavia ambition 1.8 tsi',
#  'linea emotion ()',
#  'discovery 4 tdv6 se',
#  'x1 m sport sdrive 20d',
#  'beetle 2.0',
#  'polo gt tdi',
#  'verna crdi 1.4 e',
#  'linea classic plus 1.3 multijet',
#  'city 1.3 exi',
#  'petra 1.2 el',
#  'fiesta 1.4 duratec exi',
#  'ignis 1.2 delta',
#  'swift 1.3 zxi',
#  'wagon-r  lxi',
#  '7 series 730ld',
#  'rapid 1.6 mpi style plus',
#  'city i dtec e',
#  'brio s option',
#  'corolla altis  1.8 vl',
#  'baleno vxi',
#  'scorpio lx',
#  'laura 1.8 tsi ambiente',
#  'range-rover 3.6 tdv8 vogue se',
#  'santa fe 4wd',
#  'sunny  xv',
#  'alto  vxi',
#  'i10 1.2 kappa sportz',
#  'optra magnum 2.0 lt',
#  'micra xl',
#  'creta 1.6 vtvt e plus',
#  'accord 2.4 elegance a/t',
#  'baleno alpha 1.3',
#  'i20 era 1.4 crdi',
#  'e-class  e350 edition e',
#  'terrano xv 110 ps',
#  'getz 1.5 crdi gvs',
#  '5 series 520d sport line',
#  'i10 era 1.1 itech se',
#  'city v exclusive',
#  'ecosport 1.5 tdci ambiente',
#  '5 series 523i sedan',
#  'ecosport 1.0 ecoboost platinum edition',
#  'zest-revotron 1.2t xm',
#  'a7  3.0 tdi quattro',
#  'indica vista quadrajet vx',
#  'jazz 1.2 v i vtec privilege',
#  'figo  1.5p titanium',
#  'beat  ls',
#  'polo gti',
#  'figo  1.2p titanium opt',
#  'ecosport 1.5  titanium',
#  'micra active xl',
#  'new c-class 200 kompressor',
#  'fiesta  style',
#  'verna 1.6 vtvt s',
#  'i20 1.4 asta (at)',
#  'new c-class c 220cdibe avantgarde command',
#  'elite i20  asta',
#  'verna 1.6 vtvt ex',
#  'corolla altis 1.8 g',
#  'range-rover sport  sport',
#  'optra 1.6 ls',
#  'q5 2.0 tdi premium plus',
#  'scorpio s6',
#  'corolla altis aero d 4d j',
#  '800 std',
#  'baleno zeta 1.2',
#  'countryman d',
#  's class  320 cdi',
#  'sail lt',
#  'manza club class quadrajet90 lx',
#  'ameo 1.5 tdi comfortline',
#  'xj 3.0l portfolio lwb',
#  'accord vti-l (at)',
#  'i20 asta (o)',
#  'range-rover sport se',
#  'optra magnum 1.6 lt',
#  'x3 xdrive20d',
#  'laura ambition 2.0 tdi cr',
#  'jazz 1.2 e i vtec',
#  'dzire zdi plus',
#  'sunny   xl',
#  'zest-quadrajet 1.3 xt',
#  'innova-crysta 2.4 vx 8s',
#  'city i dtec sv',
#  'q5  3.0 tdi',
#  'thar crde',
#  'aspire titanium',
#  '3 door d',
#  'optra 1.6 elite',
#  'innova 2.5 gx',
#  'ameo 1.2 mpi highline',
#  'sx4 zdi leather',
#  'q7 35 tdi quattro technology',
#  'passat  highline 2.0 tdi',
#  'discovery sport td4 hse 7s',
#  'city i vtec sv',
#  'wagon-r lx',
#  'tiguan 2.0 tdi highline',
#  'i10 1.2 crdi sportz option',
#  'jetta  2.0l tdi comfortline',
#  'yeti elegance',
#  'q7 45 tdi quattro premium plus',
#  'rapid 1.6 mpi elegance black package',
#  'q7 4.2 fsi quattro',
#  'polo 1.5 tdi comfortline',
#  'polo 1.5 tdi trendline',
#  'captiva ltz vcdi',
#  'ciaz 1.4 zeta',
#  'scorpio  vlx 4wd 7s',
#  'aveo u-va 1.2 ls',
#  'ciaz zxi option',
#  'jazz 1.2 sv i vtec',
#  'fabia 1.2 tdi ambition',
#  'i10 magna(o) with sun roof',
#  'e-class  e350 cdi avantgarde',
#  'a4 35 tdi premium',
#  'sunny  xl',
#  'aveo 1.4 ls',
#  'mobilio v i dtec',
#  'a-star vxi aktiv',
#  'new c-class c 200 kompressor elegance',
#  'i20 1.4 asta crdi with avn',
#  'octavia rider 1.9 tdi',
#  'duster  rxl',
#  'micra',
#  'q5 3.0 tdi quattro technology',
#  'punto evo 1.2 emotion',
#  'tuv 300  mhawk100 t8',
#  'endeavour 4x2 xlt limited edition',
#  'amaze v cvt',
#  '3 series 320d gt luxury line',
#  'baleno delta',
#  'etios g safety',
#  'indica v2 dls tc',
#  'figo 1.5d titanium plus',
#  'sunny xl',
#  'grande-punto 1.3 emotion ()',
#  'endeavour 3.0l 4x4',
#  'x6 xdrive 40d',
#  'wagon-r vxi option',
#  'zen-estilo 1.1 lx',
#  'verito 1.5 d6',
#  'kwid climber 1.0',
#  'cayenne',
#  'go t option',
#  '3 series 330i',
#  'eon 1.0 kappa magna plus optional',
#  'i20 sportz 1.2',
#  'ritz zxi',
#  'amaze e i-vtech',
#  'ameo 1.2 mpi trendline',
#  'ecosport 1.5 dv5 trend',
#  'etios liva 1.2 vx dual tone',
#  'bolt quadrajet xe',
#  'q5 2.0 tdi',
#  'i20 magna',
#  'kuv-100 mfalcon d75 k4 plus',
#  'elantra 1.6 sx option',
#  'compass 2.0 limited option black',
#  'vitara-brezza vdi option',
#  'corolla altis 1.8 gl',
#  'x1 xdrive 20d xline',
#  'evalia 2013 xl',
#  'countryman d high',
#  'linea t-jet active',
#  'santro dx',
#  'rapid 1.6 mpi elegance',
#  'innova 2.5 le 2014',
#  'indica v2 elx',
#  'enjoy 1.3 tcdi ls 8',
#  'fiesta 1.4 duratorq exi',
#  'gls 350d grand edition',
#  'jazz 1.2 s i vtec',
#  'scala  rxl',
#  'new c-class 250 cdi classic',
#  'qualis fs b3',
#  '5 series  525d sedan',
#  'corolla h2',
#  'e-class 200 kompressor elegance',
#  'dzire vdi',
#  'scorpio 1.99 s10',
#  'fabia 1.2l  classic',
#  'city i vtec cvt sv',
#  'sumo ex',
#  'linea 1.3 dynamic',
#  'a3 35 tdi technology',
#  'i20 1.4 crdi magna',
#  'fiesta 1.6 zxi duratec',
#  'gla class 200 d sport',
#  'innova 2.0 gx',
#  'figo 1.2p titanium',
#  '7 series 740li',
#  '3 series 320d sport',
#  'compass 2.0 longitude',
#  'xcent 1.2 vtvt sx',
#  'e-class 220 cdi',
#  'renault logan 1.4 glx',
#  'octavia 1.9 tdi',
#  'ikon 1.4 tdci duratorq',
#  'polo 1.0 mpi comfortline',
#  'scorpio vlx 2wd airbag',
#  'xylo e4',
#  'innova 2.5 g3',
#  'e-class  e 200 cgi elegance',
#  'bolero sle',
#  'ritz',
#  'scorpio 2.6 crde',
#  'scorpio s4',
#  'jeep mm 550 pe',
#  '7 series 730ld eminence',
#  'sonata embera 2.0l crdi',
#  'duster adventure edition',
#  'a4 2.0 tdi 177 bhp technology edition',
#  'verna 1.4 vtvt',
#  'tuv 300 t8',
#  'accent gle 1',
#  'swift 1.3 lxi',
#  'zest-revotron 1.2t xms',
#  'aspire titanium plus',
#  'verna sx crdi',
#  'x3 xdrive20d expedition',
#  '6 series 640d coupe',
#  'santro lp zipplus',
#  'cayenne turbo s',
#  'quanto c8',
#  'corolla h5',
#  'kuv-100 mfalcon d75 k4',
#  '3 series  325i sedan',
#  'fortuner 4x2 trd sportivo',
#  'indigo cs emax  glx',
#  'freestyle titanium',
#  'elite i20 asta option',
#  'baleno alpha 1.2',
#  'santa fe 2wd',
#  'city 1.5 v exclusive',
#  'endeavour 2.2 titanium 4x2',
#  'xuv500 w10 awd',
#  'creta 1.6 sx option',
#  'swift vdi w',
#  'scorpio sle',
#  'jetta  2.0 tdi trendline',
#  'discovery hse luxury 3.0 td6',
#  'terrano xl 110 ps',
#  'tucson 2.0 dual vtvt 2wd gl',
#  'a4 2.0 tfsi',
#  'e-class e250 cdi launch edition',
#  'duster 85ps  rxe',
#  's60 d4 summum',
#  'swift dzire 1.2 lxi',
#  'omni mpi std',
#  'sx4 vdi',
#  'fiesta titanium 1.5 tdci',
#  'e-class e270 cdi',
#  'baleno zeta',
#  'polo 1.2 mpi trendline',
#  'i20 1.2 era',
#  'camry w4 (at)',
#  '5 series  520d m sport',
#  'superb 2.5 tdi',
#  'corolla altis d-4d g',
#  'zen-estilo lxi',
#  'etios-cross 1.4l gd',
#  'celerio zxi',
#  'tiago 1.2 revotron xt',
#  'm-class ml 250 cdi',
#  'wagon-r vxi 1.2',
#  'city i-dtec zx',
#  'swift lxi option',
#  'm-class ml 350 cdi corporate',
#  'innova-crysta 2.4 g',
#  'etios liva v',
#  'qualis rs e2',
#  'x6 xdrive30d',
#  'ciaz vdi',
#  'logan  1.5 dls',
#  'ciaz alpha',
#  'figo  1.2p trend',
#  '1 series 118d sport line',
#  'safari dicor 2.2 lx 4x2',
#  'scorpio vlx 4wd airbag',
#  ...]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6017 entries, 0 to 6018
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           6017 non-null   object
#  1   Year               6017 non-null   int64
#  2   Kilometers_Driven  6017 non-null   int64
#  3   Fuel_Type          6017 non-null   object
#  4   Transmission       6017 non-null   object
#  5   Owner_Type         6017 non-null   object
#  6   Seats              6017 non-null   float64
#  7   Price              6017 non-null   float64
#  8   Mileage_Value      6017 non-null   float64
#  9   Mileage_Unit       6017 non-null   object
#  10  Engine_Value       6017 non-null   float64
#  11  Power_Value        6017 non-null   float64
#  12  Manufacturer_Name  6017 non-null   object
#  13  Model_Name         6017 non-null   object
#  14  ABS                6017 non-null   int32
#  15  BS_Version         6017 non-null   int64
#  16  Model_subName      6017 non-null   object
#  17  Model_specific     6017 non-null   object
# dtypes: float64(5), int32(1), int64(3), object(9)
# memory usage: 869.6+ KB

# %% [markdown]
# def preprocesing(df):
#     columns_to_split = ['Mileage','Engine','Power']
#     for column in columns_to_split:
#         df[[column + '_Value', column + '_Unit']] = df[column].str.split(' ', expand=True)
#         df[column + '_Value']= df[column + '_Value'].replace('null', np.nan).astype(float)
#         df = df.drop(column, axis=1)
#     df.drop(['Engine_Unit','Power_Unit','New_Price'],axis=1,inplace= True)
#     df.dropna(subset=['Mileage_Value'],inplace= True)
#
#     #cleaning Name column
#     Fuel_Types = df['Fuel_Type'].unique()
#     for Fuel_Type in Fuel_Types:
#         df['Name'] = df['Name'].str.replace(Fuel_Type, '')
#
#     df['Name'] = df['Name'].str.replace('Cooper', '').replace('Land Rover', 'Land_Rover')
#
#     df['Name'] = df['Name'].str.lower()
#
#     df[['Manufacturer_Name', 'Model_Name']] = df['Name'].str.split(' ',n=1, expand=True)
# #     df = df.drop('Name', axis=1)
#
#     name_corrections = [('wagon r', 'wagon-r'), ('f type', 'f-type'), ('redi go', 'redi-go'),('grand i10','i10')]
#     for old, new in name_corrections:
#         df['Model_Name'] = df['Model_Name'].str.replace(old, new)
#
#     df['ABS'] = df['Model_Name'].str.contains('abs', case=False).astype(int)
#     df['Model_Name'] = df['Model_Name'].str.replace('abs', '')
#
#     # Extract BS version using regular expression
#     df['BS_Version'] = df['Model_Name'].str.extract(r'(bs\s*-*[ivxlc123456]*\s*\d*)')
#     df['Model_Name'] = df['Model_Name'].str.replace(r'(bs\s*-*[ivxlc123456]*\s*\d*)', '', regex=True).str.strip()
#     df['BS_Version'] = df['BS_Version'].str.replace(r'\s*\-*','',regex=True)
#     bs_version_mapping = {'bsiv': 4, 'bsiii': 3, 'bs3': 3, 'bsii': 2, np.nan: 0}
#     df['BS_Version'] = df['BS_Version'].map(bs_version_mapping)
#
#     df[['Model_subName', 'Model_specific']] = df['Model_Name'].str.split(' ',n=1, expand=True)
#
#     columns_with_nulls = ['Seats', 'Engine_Value', 'Power_Value']
#     for column in columns_with_nulls:
#         df[column] = df[column].fillna(df.groupby(['Manufacturer_Name'])[column].transform('mean'))
#
#     df['Power_Value'] = df['Power_Value'].fillna(53.3)
#
#     return df

# %%
# train = preprocesing(train)
# test= preprocesing(test)

# %%
# Create a summary table for datasets

table = PrettyTable()
table.field_names = ["Column Name", "Unique Train", "Unique Test", "Data Type", "Minimum", "Maximum", "Null Train", "Test Null"]
table.max_width = 20
for column in test.columns:
    unique_values_train = train[column].nunique()
    unique_values_test = test[column].nunique()
    data_type = train[column].dtype
    minimum = train[column].min()
    maximum = train[column].max()
    null_count = train[column].isnull().sum()
    test_null_count = test[column].isnull().sum()

    table.add_row([column, unique_values_train, unique_values_test, data_type, minimum, maximum, null_count, test_null_count])

print(table)
# Out:
# +-------------------+--------------+-------------+-----------+--------------------+----------------------+------------+-----------+
# |    Column Name    | Unique Train | Unique Test | Data Type |      Minimum       |       Maximum        | Null Train | Test Null |
# +-------------------+--------------+-------------+-----------+--------------------+----------------------+------------+-----------+
# |      Location     |      11      |      11     |   object  |     Ahmedabad      |         Pune         |     0      |     0     |
# |        Year       |      22      |      20     |   int64   |        1998        |         2019         |     0      |     0     |
# | Kilometers_Driven |     3093     |     755     |   int64   |        171         |       6500000        |     0      |     0     |
# |     Fuel_Type     |      4       |      4      |   object  |        CNG         |        Petrol        |     0      |     0     |
# |    Transmission   |      2       |      2      |   object  |     Automatic      |        Manual        |     0      |     0     |
# |     Owner_Type    |      4       |      4      |   object  |       First        |        Third         |     0      |     0     |
# |       Seats       |      9       |      7      |  float64  |        0.0         |         10.0         |     0      |     0     |
# |   Mileage_Value   |     430      |     298     |  float64  |        0.0         |        33.54         |     0      |     0     |
# |    Mileage_Unit   |      2       |      2      |   object  |       km/kg        |         kmpl         |     0      |     0     |
# |    Engine_Value   |     152      |     111     |  float64  |       624.0        |        5998.0        |     0      |     0     |
# |    Power_Value    |     385      |     257     |  float64  |        34.2        |        560.0         |     0      |     0     |
# | Manufacturer_Name |      30      |      28     |   object  |     Land-Rover     |        volvo         |     0      |     0     |
# |     Model_Name    |     1604     |     692     |   object  | 1 series 118d base |  zest-revotron 1.2t  |     0      |     0     |
# |                   |              |             |           |                    |         xms          |            |           |
# |        ABS        |      2       |      2      |   int32   |         0          |          1           |     0      |     0     |
# |     BS_Version    |      4       |      4      |   int64   |         0          |          4           |     0      |     0     |
# |   Model_subName   |     216      |     166     |   object  |         1          |    zest-revotron     |     0      |     0     |
# |   Model_specific  |     1397     |     620     |   object  |          ac        |   zxi with leather   |     0      |     0     |
# +-------------------+--------------+-------------+-----------+--------------------+----------------------+------------+-----------+

# %%
# Categorize columns into categorical, continuous, and discrete
categorical_columns = train.select_dtypes(include=['object']).columns
numeric_columns = train.select_dtypes(include=['float64', 'int64']).columns

continuous_columns = []
discrete_columns = []

for column in train.columns:
    unique_values = train[column].nunique()
    if unique_values > 50 and train[column].dtype != 'object':
        continuous_columns.append(column)
    else:
        discrete_columns.append(column)

print("Categorical Columns:\n", ',  '.join(categorical_columns),"\n\n")
print("numeric columns:\n", ',  '.join(numeric_columns),"\n\n")
print("Continuous Columns:\n", ',  '.join(continuous_columns), "\n\n")
print("Discrete Columns:\n", ',  '.join(discrete_columns))
# Out:
# Categorical Columns:
#  Location,  Fuel_Type,  Transmission,  Owner_Type,  Mileage_Unit,  Manufacturer_Name,  Model_Name,  Model_subName,  Model_specific
#
#
# numeric columns:
#  Year,  Kilometers_Driven,  Seats,  Price,  Mileage_Value,  Engine_Value,  Power_Value,  BS_Version
#
#
# Continuous Columns:
#  Kilometers_Driven,  Price,  Mileage_Value,  Engine_Value,  Power_Value
#
#
# Discrete Columns:
#  Location,  Year,  Fuel_Type,  Transmission,  Owner_Type,  Seats,  Mileage_Unit,  Manufacturer_Name,  Model_Name,  ABS,  BS_Version,  Model_subName,  Model_specific

# %%
plt.figure(figsize=(16,8))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(2, 4, i)
    sns.boxplot(y=train[column])
    plt.title(f'Boxplot of {column}')

plt.tight_layout()
plt.show()

# %%
train[train['Kilometers_Driven'] >1000000]
# Out:
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 2328  Chennai  2017            6500000    Diesel    Automatic      First
#
#       Seats  Price  Mileage_Value Mileage_Unit  Engine_Value  Power_Value  \
# 2328    5.0   65.0          15.97         kmpl        2993.0        258.0
#
#      Manufacturer_Name             Model_Name  ABS  BS_Version Model_subName  \
# 2328               bmw  x5 xdrive 30d m sport    0           0            x5
#
#           Model_specific
# 2328  xdrive 30d m sport

# %%
train.loc[2328, 'Kilometers_Driven'] = 650000

# %%
plt.figure(figsize=(16,8))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(2, 4, i)
    sns.histplot(x=train[column])
    plt.title(f'histogram of {column}')

plt.tight_layout()
plt.show()

# %%
def log_transform(df):
    for column in columns_to_log_trans:
        df[column+"_log"] = np.log1p(df[column])
    return df

# %%
columns_to_log_trans=['Kilometers_Driven','Engine_Value','Power_Value']

# %%
train = log_transform(train)
test = log_transform(test)

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

combined_df = pd.concat([train[categorical_columns], test[categorical_columns]], axis=0)
for column in categorical_columns:
    combined_df[column]=le.fit_transform(combined_df[column])
    test[column] = le.transform(test[column])
    train[column] = le.transform(train[column])

# %%
train.head()
# Out:
#    Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0         9  2010              72000          0             1           0
# 1        10  2015              41000          1             1           0
# 2         2  2011              46000          3             1           0
# 3         2  2012              87000          1             1           0
# 4         3  2013              40670          1             0           2
#
#    Seats  Price  Mileage_Value  Mileage_Unit  ...  Power_Value  \
# 0    5.0   1.75          26.60             0  ...        58.16
# 1    5.0  12.50          19.67             1  ...       126.20
# 2    5.0   4.50          18.20             1  ...        88.70
# 3    7.0   6.00          20.77             1  ...        88.76
# 4    5.0  17.74          15.20             1  ...       140.80
#
#    Manufacturer_Name  Model_Name  ABS  BS_Version  Model_subName  \
# 0                 18        1606    0           0            199
# 1                 12         426    0           0             57
# 2                 11         952    0           0            108
# 3                 18         592    0           0             72
# 4                  2         103    0           0             12
#
#    Model_specific  Kilometers_Driven_log  Engine_Value_log  Power_Value_log
# 0            1059              11.184435          6.906755         4.080246
# 1             375              10.621352          7.367077         4.845761
# 2            1330              10.736418          7.090077         4.496471
# 3            1352              11.373675          7.130099         4.497139
# 4            1115              10.613271          7.585281         4.954418
#
# [5 rows x 21 columns]

# %%
X= train.drop(['Price'],axis=1)
y=train['Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state=0)

# %%
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error

# %%
# Initialize models
models = {
    'Linear Regression': LinearRegression(),
    'Ridge Regression': Ridge(),
    'Lasso Regression': Lasso(),
    'Random Forest': RandomForestRegressor(),
    'Gradient Boosting': GradientBoostingRegressor(),
    'Support Vector Machine': SVR(),
    'k-Nearest Neighbors': KNeighborsRegressor(),
    'Neural Network': MLPRegressor(max_iter=3000),
    'Gaussian Process': GaussianProcessRegressor(),
    'XGBoost': XGBRegressor(),
    'LightGBM': LGBMRegressor(verbose=0),
    'CatBoost': CatBoostRegressor(verbose=0) 
}

# Train the models and evaluate
best_model = None
best_mse = float('inf')

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    score = model.score(X_test,y_test)
    
    print(f"Mean Squared Error ({name}): {mse} , Score : {score}")
    
 
    if mse < best_mse:
        best_mse = mse
        best_score= score
        best_model = model

print(f"The best model is {type(best_model).__name__} with an MSE of {best_mse} and score {best_score}")
# Out:
# Mean Squared Error (Linear Regression): 35.8082208275816 , Score : 0.7292291212210567
# Mean Squared Error (Ridge Regression): 35.838398309687996 , Score : 0.7290009282765194
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.974e+03, tolerance: 5.940e+01
#   model = cd_fast.enet_coordinate_descent(
# Mean Squared Error (Lasso Regression): 40.691206284246014 , Score : 0.6923054698189905
# Mean Squared Error (Random Forest): 19.302250355119195 , Score : 0.8540422514641932
# Mean Squared Error (Gradient Boosting): 20.42595723335218 , Score : 0.8455451217024508
# Mean Squared Error (Support Vector Machine): 139.7215753286065 , Score : -0.056532071734886946
# Mean Squared Error (k-Nearest Neighbors): 70.72381492026578 , Score : 0.46520801441747994
# Mean Squared Error (Neural Network): 50.48871324596353 , Score : 0.6182197010051527
# Mean Squared Error (Gaussian Process): 223.90813255342616 , Score : -0.6931252214168719
# Mean Squared Error (XGBoost): 15.943748151396383 , Score : 0.8794382240108822
# Mean Squared Error (LightGBM): 16.716376225482364 , Score : 0.8735958454242199
# Mean Squared Error (CatBoost): 16.061253268763156 , Score : 0.8785496860395705
# The best model is XGBRegressor with an MSE of 15.943748151396383 and score 0.8794382240108822

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Define a dictionary to store the top 3 best parameters for CatBoost
top_params_catboost = []

# Define the objective function for CatBoost optimization
def objective_catboost(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 50, 1500),
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'random_strength': trial.suggest_float('random_strength', 0.1, 1.0),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1.0),
        'border_count': trial.suggest_int('border_count', 1, 255),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 0.1, 10.0),
    }
    model = CatBoostRegressor(**params, verbose=0)

    # Fit the model to the training data
    model.fit(X_train, y_train)

    # Make predictions on the test data
    predictions = model.predict(X_test)

    # Calculate mean squared error as the objective to minimize
    mse = mean_squared_error(y_test, predictions)

    # Store the top 3 best parameters for CatBoost
    top_params_catboost.append((mse, params))
    top_params_catboost.sort()

    return mse

# Create the Optuna study and optimize the objective function for CatBoost
study_catboost = optuna.create_study(direction='minimize')
study_catboost.optimize(objective_catboost, n_trials=50)

# Print the top 3 best parameters for CatBoost
print("Top 3 Best Parameters for CatBoost:")
for i, (mse, params) in enumerate(top_params_catboost[:3], 1):
    print(f"  Rank {i}: Mean Squared Error = {mse}, Parameters = {params}")
# Out:
# [I 2024-05-10 20:54:50,754] A new study created in memory with name: no-name-71020190-424c-4cc7-b6dd-2ce964fb0da7
# [I 2024-05-10 20:55:00,124] Trial 0 finished with value: 11.072679777980424 and parameters: {'iterations': 1083, 'depth': 6, 'learning_rate': 0.13104193403563044, 'random_strength': 0.27357216747546076, 'bagging_temperature': 0.3030947337427453, 'border_count': 228, 'l2_leaf_reg': 0.22026732555502856}. Best is trial 0 with value: 11.072679777980424.
# [I 2024-05-10 20:55:01,758] Trial 1 finished with value: 11.858576427259198 and parameters: {'iterations': 122, 'depth': 8, 'learning_rate': 0.2885054093185057, 'random_strength': 0.7486031420577929, 'bagging_temperature': 0.04114953098646312, 'border_count': 245, 'l2_leaf_reg': 6.371009325826948}. Best is trial 0 with value: 11.072679777980424.
# [I 2024-05-10 20:55:07,561] Trial 2 finished with value: 10.057200452567145 and parameters: {'iterations': 576, 'depth': 8, 'learning_rate': 0.20680044167951875, 'random_strength': 0.4088416842644057, 'bagging_temperature': 0.9235696515783209, 'border_count': 142, 'l2_leaf_reg': 3.27147301316815}. Best is trial 2 with value: 10.057200452567145.
# [I 2024-05-10 20:55:11,610] Trial 3 finished with value: 11.113302270218748 and parameters: {'iterations': 1227, 'depth': 4, 'learning_rate': 0.0371187218143371, 'random_strength': 0.8305632418679838, 'bagging_temperature': 0.4042338256011362, 'border_count': 252, 'l2_leaf_reg': 1.5642753762566801}. Best is trial 2 with value: 10.057200452567145.
# [I 2024-05-10 20:55:27,785] Trial 4 finished with value: 9.71595120841992 and parameters: {'iterations': 1235, 'depth': 8, 'learning_rate': 0.053377499642102866, 'random_strength': 0.6074019906921436, 'bagging_temperature': 0.8456710134758011, 'border_count': 227, 'l2_leaf_reg': 5.236963154062614}. Best is trial 4 with value: 9.71595120841992.
# [I 2024-05-10 20
. Best is trial 32 with value: 9.25110644839388.
# [I 2024-05-10 21:03:00,315] Trial 47 finished with value: 10.262178881151941 and parameters: {'iterations': 498, 'depth': 8, 'learning_rate': 0.15052062920313597, 'random_strength': 0.36413750293815283, 'bagging_temperature': 0.38981445734899495, 'border_count': 116, 'l2_leaf_reg': 1.6519039728115645}. Best is trial 32 with value: 9.25110644839388.
# [I 2024-05-10 21:03:06,491] Trial 48 finished with value: 10.504402724116456 and parameters: {'iterations': 758, 'depth': 8, 'learning_rate': 0.19343194014520507, 'random_strength': 0.26815392469926846, 'bagging_temperature': 0.4621187387776651, 'border_count': 67, 'l2_leaf_reg': 3.486480035081264}. Best is trial 32 with value: 9.25110644839388.
# [I 2024-05-10 21:03:14,410] Trial 49 finished with value: 9.76996865145509 and parameters: {'iterations': 815, 'depth': 7, 'learning_rate': 0.15867504754023876, 'random_strength': 0.19327424851250347, 'bagging_temperature': 0.5326809487985494, 'border_count': 153, 'l2_leaf_reg': 2.5663602416003504}. Best is trial 32 with value: 9.25110644839388.
# Top 3 Best Parameters for CatBoost:
#   Rank 1: Mean Squared Error = 9.25110644839388, Parameters = {'iterations': 847, 'depth': 8, 'learning_rate': 0.14160009006479568, 'random_strength': 0.4542821896814169, 'bagging_temperature': 0.36327883067280897, 'border_count': 200, 'l2_leaf_reg': 2.2235327850222015}
#   Rank 2: Mean Squared Error = 9.38993539969051, Parameters = {'iterations': 821, 'depth': 8, 'learning_rate': 0.16294082565718535, 'random_strength': 0.355730716119877, 'bagging_temperature': 0.334699535235102, 'border_count': 228, 'l2_leaf_reg': 1.048614918651805}
#   Rank 3: Mean Squared Error = 9.417846922938047, Parameters = {'iterations': 615, 'depth': 8, 'learning_rate': 0.1881137716064419, 'random_strength': 0.30535976641965545, 'bagging_temperature': 0.4958387695704377, 'border_count': 127, 'l2_leaf_reg': 2.695938950987326}

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Define a dictionary to store the top 3 best parameters for LightGBM
top_params_lightgbm = []

# Define the objective function for LightGBM optimization
def objective_lightgbm(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 2000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'num_leaves': trial.suggest_int('num_leaves', 10, 100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.35),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    }
#     params = {
#     'n_estimators': trial.suggest_int('n_estimators', 50, 5000),
#     'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.3, log=True),
#     'max_depth': trial.suggest_int('max_depth', -1, 20),  # -1 means no limit
#     'min_child_weight': trial.suggest_float('min_child_weight', 1e-3, 1.0),
#     'subsample': trial.suggest_float('subsample', 0.5, 1.0),
#     'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
#     'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
#     'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
#     'boosting_type': trial.suggest_categorical('boosting_type', ['gbdt', 'dart', 'rf']),
#     'num_leaves': trial.suggest_int('num_leaves', 2, 256),
#     'subsample_for_bin': trial.suggest_int('subsample_for_bin', 20000, 300000),
#     'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced']),
#     'min_split_gain': trial.suggest_float('min_split_gain', 0.0, 1.0),
#     'min_child_samples': trial.suggest_int('min_child_samples', 5, 50),
#     'subsample_freq': trial.suggest_int('subsample_freq', 0, 10),
#     'random_state': 42,
#     'n_jobs': trial.suggest_categorical('n_jobs', [None, -1, 1]),  # Use -1 for all threads, None for default
# }
    model = LGBMRegressor( **params,verbose=-1)

    # Fit the model to the training data
    model.fit(X_train, y_train)

    # Make predictions on the test data
    predictions = model.predict(X_test)

    # Calculate mean squared error as the objective to minimize
    mse = mean_squared_error(y_test, predictions)

    # Store the top 3 best parameters for LightGBM
    top_params_lightgbm.append((mse, params))
    top_params_lightgbm.sort()

    return mse

# Create the Optuna study and optimize the objective function for LightGBM
study_lightgbm = optuna.create_study(direction='minimize')
study_lightgbm.optimize(objective_lightgbm, n_trials=50)

# Print the top 3 best parameters for LightGBM
print("Top 3 Best Parameters for LightGBM:")
for i, (mse, params) in enumerate(top_params_lightgbm[:3], 1):
    print(f"  Rank {i}: Mean Squared Error = {mse}, Parameters = {params}")
# Out:
# [I 2024-05-10 21:03:14,460] A new study created in memory with name: no-name-b89ab1ba-c1fe-4073-b224-684275c7fc3a
# [I 2024-05-10 21:03:15,719] Trial 0 finished with value: 11.875386432019214 and parameters: {'n_estimators': 515, 'max_depth': 4, 'num_leaves': 67, 'learning_rate': 0.08342616833257976, 'subsample': 0.9837248353765824, 'colsample_bytree': 0.8753190202062857}. Best is trial 0 with value: 11.875386432019214.
# [I 2024-05-10 21:03:22,571] Trial 1 finished with value: 10.797639285047728 and parameters: {'n_estimators': 927, 'max_depth': 8, 'num_leaves': 94, 'learning_rate': 0.12450359067046622, 'subsample': 0.9467270487512842, 'colsample_bytree': 0.6657138816892474}. Best is trial 1 with value: 10.797639285047728.
# [I 2024-05-10 21:03:30,911] Trial 2 finished with value: 9.320497738495675 and parameters: {'n_estimators': 1053, 'max_depth': 10, 'num_leaves': 53, 'learning_rate': 0.14622467303313538, 'subsample': 0.6549326035487733, 'colsample_bytree': 0.7399765097930562}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:34,709] Trial 3 finished with value: 11.67190610039489 and parameters: {'n_estimators': 901, 'max_depth': 9, 'num_leaves': 68, 'learning_rate': 0.11551446717569686, 'subsample': 0.543974894070256, 'colsample_bytree': 0.9720218975621144}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:39,525] Trial 4 finished with value: 11.219890079010678 and parameters: {'n_estimators': 1404, 'max_depth': 7, 'num_leaves': 51, 'learning_rate': 0.08703007214986187, 'subsample': 0.7588936636466272, 'colsample_bytree': 0.7678447404697396}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:40,563] Trial 5 finished with value: 11.283307440761583 and parameters: {'n_estimators': 950, 'max_depth': 3, 'num_leaves': 76, 'learning_rate': 0.18964385908632567, 'subsample': 0.6733812058611192, 'colsample_bytree': 0.6586899065416886}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:46,642] Trial 6 finished with value: 10.48768836283838 and parameters: {'n_estimators': 1615, 'max_depth': 9, 'num_leaves': 77, 'learning_rate': 0.11117964404591892, 'subsample': 0.8015783566721042, 'colsample_bytree': 0.8596826168660947}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:49,958] Trial 7 finished with value: 11.069568310939253 and parameters: {'n_estimators': 1238, 'max_depth': 9, 'num_leaves': 75, 'learning_rate': 0.11281004320368974, 'subsample': 0.9465531278568233, 'colsample_bytree': 0.8860690817372485}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:50,552] Trial 8 finished with value: 10.789878138930392 and parameters: {'n_estimators': 1028, 'max_depth': 3, 'num_leaves': 70, 'learning_rate': 0.09036450400639838, 'subsample': 0.7985447005242959, 'colsample_bytree': 0.6041057115773836}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:50,935] Trial 9 finished with value: 10.384251139972472 and parameters: {'n_estimators': 175, 'max_depth': 9, 'num_leaves': 54, 'learning_rate': 0.07806213064798814, 'subsample': 0.6262775396170007, 'colsample_bytree': 0.5997462712213111}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:53,087] Trial 10 finished with value: 11.12361232619396 and parameters: {'n_estimators': 1933, 'max_depth': 5, 'num_leaves': 22, 'learning_rate': 0.26335037833907204, 'subsample': 0.5232261836592309, 'colsample_bytree': 0.5306371177153701}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:53,478] Trial 11 finished with value: 13.748186601676633 and parameters: {'n_estimators': 91, 'max_depth': 10, 'num_leaves': 43, 'learning_rate': 0.034280282360664965, 'subsample': 0.6086116470276921, 'colsample_bytree': 0.7343796353262295}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:54,462] Trial 12 finished with value: 9.372485957741192 and parameters: {'n_estimators': 441, 'max_depth': 10, 'num_leaves': 36, 'learning_rate': 0.1883558417560695, 'subsample': 0.6341169302718992, 'colsample_bytree': 0.5129650914340497}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:55,900] Trial 13 finished with value: 10.194698364469454 and parameters: {'n_estimators': 536, 'max_depth': 10, 'num_leaves': 32, 'learning_rate': 0.19482887723795542, 'subsample': 0.6892381161183166, 'colsample_bytree': 0.5592679058797918}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:56,698] Trial 14 finished with value: 9.730080903119289 and parameters: {'n_estimators': 541, 'max_depth': 6, 'num_leaves': 13, 'learning_rate': 0.33855939003222485, 'subsample': 0.5798440467856193, 'colsample_bytree': 0.5027347908754426}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:58,817] Trial 15 finished with value: 10.698089726435256 and parameters: {'n_estimators': 667, 'max_depth': 7, 'num_leaves': 40, 'learning_rate': 0.15744216084414617, 'subsample': 0.6626289974505808, 'colsample_bytree': 0.7352494912345944}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:03:59,799] Trial 16 finished with value: 9.77550819935136 and parameters: {'n_estimators': 290, 'max_depth': 10, 'num_leaves': 30, 'learning_rate': 0.2252729858342113, 'subsample': 0.5058033500343562, 'colsample_bytree': 0.5025367946361219}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04:04,065] Trial 17 finished with value: 9.341186742230345 and parameters: {'n_estimators': 1269, 'max_depth': 8, 'num_leaves': 45, 'learning_rate': 0.16152882904841787, 'subsample': 0.7134372042866476, 'colsample_bytree': 0.6583408244233202}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04:09,970] Trial 18 finished with value: 10.184648269715973 and parameters: {'n_estimators': 1548, 'max_depth': 8, 'num_leaves': 60, 'learning_rate': 0.1611606547643312, 'subsample': 0.7165128006185881, 'colsample_bytree': 0.6685026573957775}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04:14,690] Trial 19 finished with value: 10.231122829287083 and parameters: {'n_estimators': 1215, 'max_depth': 8, 'num_leaves': 91, 'learning_rate': 0.14724907036005014, 'subsample': 0.7397544847124624, 'colsample_bytree': 0.779345312568378}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04:19,668] Trial 20 finished with value: 11.090201985161322 and parameters: {'n_estimators': 1841, 'max_depth': 6, 'num_leaves': 50, 'learning_rate': 0.010071576572993957, 'subsample': 0.5568177400522392, 'colsample_bytree': 0.7150539052385296}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04:24,204] Trial 21 finished with value: 9.967077815135106 and parameters: {'n_estimators': 1131, 'max_depth': 10, 'num_leaves': 43, 'learning_rate': 0.2136738330643162, 'subsample': 0.6315030394935487, 'colsample_bytree': 0.5815398472265951}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04
. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04:56,562] Trial 35 finished with value: 10.904529751760535 and parameters: {'n_estimators': 846, 'max_depth': 6, 'num_leaves': 16, 'learning_rate': 0.1325796831357577, 'subsample': 0.6663334206377461, 'colsample_bytree': 0.5652790409865281}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:04:57,293] Trial 36 finished with value: 11.859556604584158 and parameters: {'n_estimators': 212, 'max_depth': 8, 'num_leaves': 35, 'learning_rate': 0.34399820886510357, 'subsample': 0.6245440966566638, 'colsample_bytree': 0.638962550133721}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:05:01,940] Trial 37 finished with value: 10.545875220521678 and parameters: {'n_estimators': 1215, 'max_depth': 9, 'num_leaves': 65, 'learning_rate': 0.31185318315811905, 'subsample': 0.5029841058496345, 'colsample_bytree': 0.5741743145841832}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:05:05,742] Trial 38 finished with value: 9.604599064726132 and parameters: {'n_estimators': 1013, 'max_depth': 9, 'num_leaves': 52, 'learning_rate': 0.2567125494114671, 'subsample': 0.6942237842365473, 'colsample_bytree': 0.5411052141903581}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:05:09,639] Trial 39 finished with value: 10.561440519967745 and parameters: {'n_estimators': 995, 'max_depth': 9, 'num_leaves': 64, 'learning_rate': 0.20724755835848258, 'subsample': 0.7534152816367704, 'colsample_bytree': 0.5443992637041404}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:05:15,902] Trial 40 finished with value: 9.837136414780447 and parameters: {'n_estimators': 1402, 'max_depth': 10, 'num_leaves': 57, 'learning_rate': 0.24240601235236076, 'subsample': 0.7106072524287506, 'colsample_bytree': 0.609308813132658}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:05:21,020] Trial 41 finished with value: 10.628617695929556 and parameters: {'n_estimators': 1282, 'max_depth': 9, 'num_leaves': 54, 'learning_rate': 0.27396763344902797, 'subsample': 0.6673336967232022, 'colsample_bytree': 0.52739051599409}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:05:25,489] Trial 42 finished with value: 10.012717671168176 and parameters: {'n_estimators': 1103, 'max_depth': 10, 'num_leaves': 45, 'learning_rate': 0.24136525965927128, 'subsample': 0.6834956703016128, 'colsample_bytree': 0.5025475374712646}. Best is trial 2 with value: 9.320497738495675.
# [I 2024-05-10 21:05:28,903] Trial 43 finished with value: 9.110448550725419 and parameters: {'n_estimators': 954, 'max_depth': 9, 'num_leaves': 52, 'learning_rate': 0.12299865426847066, 'subsample': 0.6158558147808533, 'colsample_bytree': 0.5376955808637683}. Best is trial 43 with value: 9.110448550725419.
# [I 2024-05-10 21:05:33,875] Trial 44 finished with value: 9.878228969271484 and parameters: {'n_estimators': 1502, 'max_depth': 8, 'num_leaves': 70, 'learning_rate': 0.1199770850278532, 'subsample': 0.6160800088893299, 'colsample_bytree': 0.5389881043517832}. Best is trial 43 with value: 9.110448550725419.
# [I 2024-05-10 21:05:38,008] Trial 45 finished with value: 10.49871066973473 and parameters: {'n_estimators': 987, 'max_depth': 9, 'num_leaves': 53, 'learning_rate': 0.10711155619005938, 'subsample': 0.6520210815207593, 'colsample_bytree': 0.5898458766066774}. Best is trial 43 with value: 9.110448550725419.
# [I 2024-05-10 21:05:42,968] Trial 46 finished with value: 10.264559135939296 and parameters: {'n_estimators': 1308, 'max_depth': 9, 'num_leaves': 39, 'learning_rate': 0.15486744817547649, 'subsample': 0.7896331239160872, 'colsample_bytree': 0.6190758707348861}. Best is trial 43 with value: 9.110448550725419.
# [I 2024-05-10 21:05:47,882] Trial 47 finished with value: 10.295933773036321 and parameters: {'n_estimators': 1167, 'max_depth': 10, 'num_leaves': 50, 'learning_rate': 0.17986992545661723, 'subsample': 0.730608391869987, 'colsample_bytree': 0.5693699298953724}. Best is trial 43 with value: 9.110448550725419.
# [I 2024-05-10 21:05:51,495] Trial 48 finished with value: 10.173165382979656 and parameters: {'n_estimators': 1050, 'max_depth': 9, 'num_leaves': 43, 'learning_rate': 0.0993008350246172, 'subsample': 0.6957595059139956, 'colsample_bytree': 0.5248459944765945}. Best is trial 43 with value: 9.110448550725419.
# [I 2024-05-10 21:05:54,741] Trial 49 finished with value: 9.124892963221333 and parameters: {'n_estimators': 912, 'max_depth': 10, 'num_leaves': 29, 'learning_rate': 0.12333459912103381, 'subsample': 0.7624540955727185, 'colsample_bytree': 0.5958694086211667}. Best is trial 43 with value: 9.110448550725419.
# Top 3 Best Parameters for LightGBM:
#   Rank 1: Mean Squared Error = 9.110448550725419, Parameters = {'n_estimators': 954, 'max_depth': 9, 'num_leaves': 52, 'learning_rate': 0.12299865426847066, 'subsample': 0.6158558147808533, 'colsample_bytree': 0.5376955808637683}
#   Rank 2: Mean Squared Error = 9.124892963221333, Parameters = {'n_estimators': 912, 'max_depth': 10, 'num_leaves': 29, 'learning_rate': 0.12333459912103381, 'subsample': 0.7624540955727185, 'colsample_bytree': 0.5958694086211667}
#   Rank 3: Mean Squared Error = 9.320497738495675, Parameters = {'n_estimators': 1053, 'max_depth': 10, 'num_leaves': 53, 'learning_rate': 0.14622467303313538, 'subsample': 0.6549326035487733, 'colsample_bytree': 0.7399765097930562}

# %%
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Define a dictionary to store the top 3 best parameters for XGBoost
top_params_xgboost = []

# Define the objective function for XGBoost optimization
def objective_xgboost(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 2000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    }
    model = XGBRegressor(**params, objective='reg:squarederror', verbosity=0)

    # Fit the model to the training data
    model.fit(X_train, y_train)

    # Make predictions on the test data
    predictions = model.predict(X_test)

    # Calculate mean squared error as the objective to minimize
    mse = mean_squared_error(y_test, predictions)

    # Store the top 3 best parameters for XGBoost
    top_params_xgboost.append((mse, params))
    top_params_xgboost.sort()

    return mse

# Create the Optuna study and optimize the objective function for XGBoost
study_xgboost = optuna.create_study(direction='minimize')
study_xgboost.optimize(objective_xgboost, n_trials=50)

# Print the top 3 best parameters for XGBoost
print("Top 3 Best Parameters for XGBoost:")
for i, (mse, params) in enumerate(top_params_xgboost[:3], 1):
    print(f"  Rank {i}: Mean Squared Error = {mse}, Parameters = {params}")
# Out:
# [I 2024-05-10 21:05:54,774] A new study created in memory with name: no-name-d0a2ec5a-6a70-4d7c-b1b4-77f1fb83230f
# [I 2024-05-10 21:06:00,250] Trial 0 finished with value: 12.952692416710617 and parameters: {'n_estimators': 1297, 'max_depth': 6, 'learning_rate': 0.23687197152810946, 'subsample': 0.7131231293793294, 'colsample_bytree': 0.6923678841467238}. Best is trial 0 with value: 12.952692416710617.
# [I 2024-05-10 21:06:08,305] Trial 1 finished with value: 11.323456136647852 and parameters: {'n_estimators': 1423, 'max_depth': 7, 'learning_rate': 0.09596940150843578, 'subsample': 0.8110799564023807, 'colsample_bytree': 0.6783646489885143}. Best is trial 1 with value: 11.323456136647852.
# [I 2024-05-10 21:06:09,815] Trial 2 finished with value: 11.504554389248257 and parameters: {'n_estimators': 621, 'max_depth': 4, 'learning_rate': 0.026789383893308115, 'subsample': 0.5424654478844417, 'colsample_bytree': 0.7812260574245755}. Best is trial 1 with value: 11.323456136647852.
# [I 2024-05-10 21:06:16,287] Trial 3 finished with value: 14.458578039717262 and parameters: {'n_estimators': 782, 'max_depth': 9, 'learning_rate': 0.2831633774510736, 'subsample': 0.8282202509892855, 'colsample_bytree': 0.5986449369251164}. Best is trial 1 with value: 11.323456136647852.
# [I 2024-05-10 21:06:19,982] Trial 4 finished with value: 10.939488191917137 and parameters: {'n_estimators': 1885, 'max_depth': 3, 'learning_rate': 0.249291966325881, 'subsample': 0.9221616658581879, 'colsample_bytree': 0.6755589449919555}. Best is trial 4 with value: 10.939488191917137.
# [I 2024-05-10 21:06:21,876] Trial 5 finished with value: 11.724260166393481 and parameters: {'n_estimators': 703, 'max_depth': 4, 'learning_rate': 0.12730747315543645, 'subsample': 0.9375930806192319, 'colsample_bytree': 0.9073455604371163}. Best is trial 4 with value: 10.939488191917137.
# [I 2024-05-10 21:06:24,818] Trial 6 finished with value: 13.423592515595818 and parameters: {'n_estimators': 1120, 'max_depth': 4, 'learning_rate': 0.28375392764206947, 'subsample': 0.7191183223451725, 'colsample_bytree': 0.8958329619734902}. Best is trial 4 with value: 10.939488191917137.
# [I 2024-05-10 21:06:33,935] Trial 7 finished with value: 13.333820273795627 and parameters: {'n_estimators': 901, 'max_depth': 10, 'learning_rate': 0.1389356866394156, 'subsample': 0.6669713524347223, 'colsample_bytree': 0.5325455728561602}. Best is trial 4 with value: 10.939488191917137.
# [I 2024-05-10 21:06:47,378] Trial 8 finished with value: 11.832258722025083 and parameters: {'n_estimators': 1214, 'max_depth': 9, 'learning_rate': 0.09624645064088089, 'subsample': 0.7988307822428528, 'colsample_bytree': 0.8786523507438144}. Best is trial 4 with value: 10.939488191917137.
# [I 2024-05-10 21:06:51,903] Trial 9 finished with value: 12.547250585242331 and parameters: {'n_estimators': 593, 'max_depth': 8, 'learning_rate': 0.17367756409122312, 'subsample': 0.5492402436751813, 'colsample_bytree': 0.6321225741780493}. Best is trial 4 with value: 10.939488191917137.
# [I 2024-05-10 21:06:55,803] Trial 10 finished with value: 10.706602692201908 and parameters: {'n_estimators': 1963, 'max_depth': 3, 'learning_rate': 0.21827710162283523, 'subsample': 0.9958626015681767, 'colsample_bytree': 0.7730846337327517}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:06:59,760] Trial 11 finished with value: 11.579534758219642 and parameters: {'n_estimators': 1979, 'max_depth': 3, 'learning_rate': 0.21878750056171106, 'subsample': 0.9923658616045511, 'colsample_bytree': 0.7922847126609897}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21
. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:08:55,814] Trial 41 finished with value: 13.100046613451857 and parameters: {'n_estimators': 972, 'max_depth': 5, 'learning_rate': 0.29704747111549723, 'subsample': 0.8560846226571223, 'colsample_bytree': 0.6747974208523049}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:08:59,474] Trial 42 finished with value: 12.8494159839859 and parameters: {'n_estimators': 1078, 'max_depth': 5, 'learning_rate': 0.2662275235588064, 'subsample': 0.7842281706040583, 'colsample_bytree': 0.6875446963516574}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:09:07,575] Trial 43 finished with value: 14.004483027279887 and parameters: {'n_estimators': 1175, 'max_depth': 8, 'learning_rate': 0.2858848465468214, 'subsample': 0.839268424493362, 'colsample_bytree': 0.7216317258391487}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:09:11,660] Trial 44 finished with value: 13.618913397452609 and parameters: {'n_estimators': 898, 'max_depth': 6, 'learning_rate': 0.29878358674329547, 'subsample': 0.9270205668478322, 'colsample_bytree': 0.7546291905097531}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:09:16,358] Trial 45 finished with value: 11.972546055811689 and parameters: {'n_estimators': 1901, 'max_depth': 4, 'learning_rate': 0.25697894161262336, 'subsample': 0.8766995526780255, 'colsample_bytree': 0.6597068808772538}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:09:18,432] Trial 46 finished with value: 11.368691849957049 and parameters: {'n_estimators': 648, 'max_depth': 5, 'learning_rate': 0.2844027163185986, 'subsample': 0.8236800851223295, 'colsample_bytree': 0.6409700110327573}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:09:21,027] Trial 47 finished with value: 11.765153120924197 and parameters: {'n_estimators': 1301, 'max_depth': 3, 'learning_rate': 0.2276275001849573, 'subsample': 0.9054645687230479, 'colsample_bytree': 0.7049526197191609}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:09:29,064] Trial 48 finished with value: 16.73723239373535 and parameters: {'n_estimators': 1936, 'max_depth': 6, 'learning_rate': 0.2475344970215304, 'subsample': 0.9804720309047843, 'colsample_bytree': 0.61576034586873}. Best is trial 10 with value: 10.706602692201908.
# [I 2024-05-10 21:09:36,992] Trial 49 finished with value: 13.78744707030602 and parameters: {'n_estimators': 814, 'max_depth': 10, 'learning_rate': 0.1623243094830609, 'subsample': 0.9455749699291554, 'colsample_bytree': 0.6774827786663256}. Best is trial 10 with value: 10.706602692201908.
# Top 3 Best Parameters for XGBoost:
#   Rank 1: Mean Squared Error = 10.706602692201908, Parameters = {'n_estimators': 1963, 'max_depth': 3, 'learning_rate': 0.21827710162283523, 'subsample': 0.9958626015681767, 'colsample_bytree': 0.7730846337327517}
#   Rank 2: Mean Squared Error = 10.939488191917137, Parameters = {'n_estimators': 1885, 'max_depth': 3, 'learning_rate': 0.249291966325881, 'subsample': 0.9221616658581879, 'colsample_bytree': 0.6755589449919555}
#   Rank 3: Mean Squared Error = 10.955705233995324, Parameters = {'n_estimators': 1029, 'max_depth': 5, 'learning_rate': 0.2924891629408452, 'subsample': 0.8512077145853907, 'colsample_bytree': 0.6785348259128207}

# %%
best_params_catboost = [item[1] for item in top_params_catboost[:3]]
best_params_xgboost = [item[1] for item in top_params_xgboost[:3]]
best_params_lightgbm = [item[1] for item in top_params_lightgbm[:3]]

# %%
models = {
    'CatBoost': CatBoostRegressor(**best_params_catboost[0], verbose=0),
    'CatBoost1': CatBoostRegressor(**best_params_catboost[1], verbose=0),
    'CatBoost2': CatBoostRegressor(**best_params_catboost[2], verbose=0),
    'XGBoost': XGBRegressor(**best_params_xgboost[0], objective='reg:squarederror', verbosity=0),
    'XGBoost1': XGBRegressor(**best_params_xgboost[1], objective='reg:squarederror', verbosity=0),
    'XGBoost2': XGBRegressor(**best_params_xgboost[2], objective='reg:squarederror', verbosity=0),
    'LightGBM': LGBMRegressor(**best_params_lightgbm[0], verbose=-1),
    'LightGBM1': LGBMRegressor(**best_params_lightgbm[1], verbose=-1),
    'LightGBM2': LGBMRegressor(**best_params_lightgbm[2], verbose=-1)
}

# %%
sum_prediction=0
model_predictions = {}
for model_name, model in models.items():
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    model_predictions[model_name] = predictions
    sum_prediction= predictions + sum_prediction
    mse= mean_squared_error(y_test, predictions)
    print(f'mean squared error - {model_name}: {mse}')
    
Ensemble_pred= sum_prediction/len(models)
Ensemble_mse= mean_squared_error(y_test, Ensemble_pred)
print(f'mean squared error - Ensemble: {Ensemble_mse}')
# Out:
# mean squared error - CatBoost: 9.25110644839388
# mean squared error - CatBoost1: 9.38993539969051
# mean squared error - CatBoost2: 9.417846922938047
# mean squared error - XGBoost: 10.706602692201908
# mean squared error - XGBoost1: 10.939488191917137
# mean squared error - XGBoost2: 10.955705233995324
# mean squared error - LightGBM: 9.110448550725419
# mean squared error - LightGBM1: 9.124892963221333
# mean squared error - LightGBM2: 9.320497738495675
# mean squared error - Ensemble: 8.719571371956654

# %%
import itertools

prediction_sets = model_predictions

# Get the list of prediction set names
prediction_set_names = list(prediction_sets.keys())

# Define a function to compute the average of a list of prediction sets
def compute_average(prediction_sets_list):
    return sum(prediction_sets_list) / len(prediction_sets_list)

best_combo_mse= float('inf')
for r in range(1, len(prediction_set_names) + 1):
    for combo in itertools.combinations(prediction_set_names, r):
        combination_name = '_'.join(combo) + '_avg'
        combination_prediction_sets = [prediction_sets[model] for model in combo]
        average_prediction = compute_average(combination_prediction_sets)
        Ensemble_mse= mean_squared_error(y_test, average_prediction)
#         print(f'Log Loss - {combo} Ensemble: {Ensemble_mse}')
        if Ensemble_mse < best_combo_mse:
            best_combo_mse =Ensemble_mse
            best_combo = combo
print(f'\nbest combo: {best_combo} \t mse {best_combo_mse}')
# Out:
# best combo: ('CatBoost', 'CatBoost1', 'LightGBM', 'LightGBM1') 	 mse 8.450336536001917

# %%
sum_prediction=0
final_model_predictions = {}
for model_name, model in models.items():
    if model_name in best_combo:
        model.fit(X, y)
        predictions = model.predict(test)
        model_predictions[model_name + '_pred'] = predictions
        sum_prediction= predictions + sum_prediction
    
Ensemble_pred= sum_prediction/len(best_combo)

# %%
Ensemble_pred
# Out:
# array([ 2.1589629 ,  2.82564139, 13.95449229, ...,  2.75933566,
#         4.81308976, 19.57285336])

# %%
submission = pd.DataFrame({'Price':Ensemble_pred})

# %%
submission.head()
# Out:
#        Price
# 0   2.158963
# 1   2.825641
# 2  13.954492
# 3   4.733781
# 4   4.315859

# %%
submission.to_csv('submission.csv')
